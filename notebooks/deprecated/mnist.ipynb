# %%
import numpy as np
import torch
import math
import os
import pickle
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import torch.nn.init as init
from torchvision.datasets import MNIST

# %%
DATA_DIR = '/content/drive/MyDrive/AML_project/datasets/MNIST_DATASET'
SEED = 42
K = 256
BATCH_SIZE = 100
LR = 1e-4 # learning rate
BETA = 1e-3 # rate distortion hyperparam
BETA_DECAY = 0.999 # EMA exponential decay
SAVE_DIR = '/content/drive/MyDrive/AML_project'
MODEL_SAVE_PATH = '/content/drive/MyDrive/AML_project/saved_models/mnist_model.h5'
EMA_SAVE_PATH = '/content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5'
PICKLE_SAVE_PATH = '/content/drive/MyDrive/AML_project/pickles/mnist_stats.pkl'
LOAD_MODEL = False
MC_SAMPLE_SIZE = 12
EPOCHS = 200 # in the paprt they did 200 epochs

# %%
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
if os.path.isdir(DATA_DIR):
    train_data = MNIST(root=DATA_DIR, train=True, transform=transforms.ToTensor())
    test_data = MNIST(root=DATA_DIR, train=False, transform=transforms.ToTensor())
else:
    train_data = MNIST(root=DATA_DIR, train=True, download=True, transform=transforms.ToTensor())
    test_data = MNIST(root=DATA_DIR, train=False, download=True, transform=transforms.ToTensor())
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting /content/drive/MyDrive/MNIST_DATASET/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/MNIST_DATASET/MNIST/raw

# %%
train_loader = DataLoader(train_data,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=1,
                          drop_last=True)

test_loader = DataLoader(test_data,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=1,
                         drop_last=False)

# %%
def reparametrize(mu, std):
    """
    Performs reparameterization trick z = mu + epsilon * std
    Where epsilon~N(0,1)
    """
    mu = mu.expand(1, *mu.size())
    std = std.expand(1, *std.size())
    eps = torch.normal(0, 1, size=std.size()).to(device)
    return mu + eps * std

def evaluate(model, model_ema):
    model.eval()
    model_ema.model.eval()
    total_iterations = 0

    class_loss = 0
    info_loss = 0
    total_loss = 0
    izy_bound = 0
    izx_bound = 0
    correct = 0
    avg_correct = 0

    class_loss_ema = 0
    info_loss_ema = 0
    total_loss_ema = 0
    izy_bound_ema = 0
    izx_bound_ema = 0
    correct_ema = 0
    avg_correct_ema = 0
    total_num = 0

    for idx, (images, labels) in enumerate(test_loader):

        x = images.to(device)
        y = labels.to(device)

        (mu, std), logit = model(x)
        (mu_ema, std_ema), logit_ema = model_ema.model(x)

        class_loss += F.cross_entropy(logit, y).div(math.log(2))
        info_loss += -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum().div(math.log(2))
        total_loss += class_loss + BETA * info_loss

        # TODO: check if size_average=False is needed here
        class_loss_ema += F.cross_entropy(logit_ema, y).div(math.log(2)) # reduction='sum'
        info_loss_ema += -0.5 * (1 + 2 * std_ema.log() - mu_ema.pow(2) - std_ema.pow(2)).sum().div(math.log(2))
        total_loss_ema += class_loss_ema + BETA * info_loss_ema

        total_num += y.size(0)
        total_iterations += 1

        # the math.log(10,2) is the entropy of the uniform RV for 10 examples in bits
        # (not expectation cause we assume it's unifrom).
        # This is negative in sign because we switch from a loss to a gain function
        izy_bound += math.log(10,2) - F.cross_entropy(logit, y).div(math.log(2))
        izx_bound += -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum().div(math.log(2))

        izy_bound_ema += math.log(10,2) - F.cross_entropy(logit_ema, y).div(math.log(2)) # reduction='sum'
        izx_bound_ema += -0.5 * (1 + 2 * std_ema.log() - mu_ema.pow(2) - std_ema.pow(2)).sum().div(math.log(2))

        prediction = F.softmax(logit, dim=1).max(1)[1]
        correct += torch.eq(prediction, y).float().sum()

        prediction_ema = F.softmax(logit_ema, dim=1).max(1)[1]
        correct_ema += torch.eq(prediction_ema, y).float().sum()

        # TODO: add MC logic
        avg_correct = torch.zeros(correct.size()).to(device)
        avg_correct_ema = torch.zeros(correct_ema.size()).to(device)

    accuracy = correct / total_num
    avg_accuracy = avg_correct / total_num

    accuracy_ema = correct_ema / total_num
    avg_accuracy_ema = avg_correct_ema / total_num

    izy_bound /= total_iterations
    izx_bound /= total_num
    class_loss /= total_num
    info_loss /= total_num
    total_loss /= total_num

    izy_bound_ema /= total_iterations
    izx_bound_ema /= total_num
    class_loss_ema /= total_num
    info_loss_ema /= total_num
    total_loss_ema /= total_num

    book_keeper['test_izx'].append(izx_bound.data.item())
    book_keeper['test_izy'].append(izy_bound.data.item())
    book_keeper['test_acc'].append(accuracy.data.item())
    book_keeper['test_error'].append(1 - accuracy.data.item())
    book_keeper['test_class_loss'].append(class_loss.data.item())
    book_keeper['test_info_loss'].append(info_loss.data.item())
    book_keeper['test_total_loss'].append(total_loss.data.item())
    book_keeper['test_izx_ema'].append(izx_bound_ema.data.item())
    book_keeper['test_izy_ema'].append(izy_bound_ema.data.item())
    book_keeper['test_acc_ema'].append(accuracy_ema.data.item())
    book_keeper['test_error_ema'].append(1 - accuracy_ema.data.item())
    book_keeper['test_class_loss_ema'].append(class_loss_ema.data.item())
    book_keeper['test_info_loss_ema'].append(info_loss_ema.data.item())
    book_keeper['test_total_loss_ema'].append(total_loss_ema.data.item())

    print('[TEST RESULT - regular]')
    print('e:{} IZY:{:.2f} IZX:{:.2f}'
            .format(e, izy_bound.data.item(), izx_bound.data.item()), end=' ')
    print('acc:{:.4f} avg_acc:{:.4f}'
            .format(accuracy.data.item(), avg_accuracy.data.item()), end=' ')
    print('err:{:.4f} avg_erra:{:.4f}'
            .format(1 - accuracy.data.item(), 1 - avg_accuracy.data.item()))
    
    print('[TEST RESULT - ema]')
    print('e:{} IZY:{:.2f} IZX:{:.2f}'
            .format(e, izy_bound_ema.data.item(), izx_bound_ema.data.item()), end=' ')
    print('acc:{:.4f} avg_acc:{:.4f}'
            .format(accuracy_ema.data.item(), avg_accuracy_ema.data.item()), end=' ')
    print('err:{:.4f} avg_erra:{:.4f}'
            .format(1 - accuracy_ema.data.item(), 1 - avg_accuracy_ema.data.item()))
    print()

    if history['acc'] < accuracy.data.item():
        history['acc'] = accuracy.data.item()
        history['avg_acc'] = avg_accuracy.data.item()
        history['class_loss'] = class_loss.data.item()
        history['info_loss'] = info_loss.data.item()
        history['total_loss'] = total_loss.data.item()
        history['epoch'] = e
        history['iter'] = iterations
        torch.save(model, MODEL_SAVE_PATH)
        print('Saved model to {}'.format(MODEL_SAVE_PATH))
    
    if history_ema['acc'] < accuracy_ema.data.item():
        history_ema['acc'] = accuracy_ema.data.item()
        history_ema['avg_acc'] = avg_accuracy_ema.data.item()
        history_ema['class_loss'] = class_loss_ema.data.item()
        history_ema['info_loss'] = info_loss_ema.data.item()
        history_ema['total_loss'] = total_loss_ema.data.item()
        history_ema['epoch'] = e
        history_ema['iter'] = iterations
        torch.save(model_ema, EMA_SAVE_PATH)
        print('Saved model to {}'.format(EMA_SAVE_PATH))

    model.train()
    model_ema.model.train()

# %%
class MNIST_IB_VAE(nn.Module):
    """
    Direct implementation of the paper's MNIST net
    Only one shot eval (no MC) - work well for beta <= 1e-3
    """
    def __init__(self, k=K):
        super(MNIST_IB_VAE, self).__init__()
        self.k = k

        self.encoder = nn.Sequential(
            nn.Linear(784, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 2 * self.k))

        self.decoder = nn.Sequential(
                nn.Linear(self.k, 10))

        # Xavier initialization
        for _, module in self._modules.items():
            for layer in module:
                if isinstance(layer, nn.Linear) or isinstance(layer, nn.Conv2d):
                            nn.init.xavier_uniform_(layer.weight, gain=nn.init.calculate_gain('relu'))
                            layer.bias.data.zero_()

    def forward(self, x):
        # squiwsh from shape (100,1,28,28) to (100,784)
        x = x.view(x.size(0),-1)
        z_params = self.encoder(x)
        mu = z_params[:, :self.k]
        # softplus transformation (soft relu) and a -5 bias is added as in the paper
        std = F.softplus(z_params[:, self.k:] - 5, beta=1)
        z = reparametrize(mu, std)
        logit = self.decoder(z)
        return (mu, std), logit[0]

class EMA_smoothning(object):
    """
    Performs exponential moving average smoothing on model updates as per
    Polyak & Juditsky, 1992.
    This will be used as a second network refference when evaluating.
    """
    def __init__(self, model, state_dict, beta_decay=0.999):
        self.model = model
        self.model.load_state_dict(state_dict, strict=True)
        self.beta_decay = beta_decay

    def update(self, new_state_dict):
        state_dict = self.model.state_dict()
        for key in state_dict.keys():
            state_dict[key] = (self.beta_decay) * state_dict[key] + (1 - self.beta_decay) * new_state_dict[key]
        self.model.load_state_dict(state_dict)

# %%
if LOAD_MODEL:
    model = torch.load(os.path.join(MODEL_SAVE_PATH)
else:
    model = MNIST_IB_VAE(k=K).to(device)

model_ema = EMA_smoothning(MNIST_IB_VAE(k=K).to(device), model.state_dict(),
                           beta_decay=BETA_DECAY)

optimizer = optim.Adam(model.parameters(), lr=LR, betas=(0.5,0.999))
scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.97)

history = dict()
history['acc']=0.
history['avg_acc']=0.
history['info_loss']=0.
history['class_loss']=0.
history['total_loss']=0.
history['epoch']=0
history['iter']=0

history_ema = dict()
history_ema['acc']=0.
history_ema['avg_acc']=0.
history_ema['info_loss']=0.
history_ema['class_loss']=0.
history_ema['total_loss']=0.
history_ema['epoch']=0
history_ema['iter']=0

keys = [
        'test_izx', 'test_izy', 'test_acc', 'test_error',
        'test_izx_ema', 'test_izy_ema', 'test_acc_ema', 'test_error_ema',
        'test_class_loss', 'test_info_loss', 'test_total_loss',
        'test_class_loss_ema', 'test_info_loss_ema', 'test_total_loss_ema',
        'train_izx', 'train_izy', 'train_acc', 'train_error', 'train_izx_ema',
        'train_izy_ema', 'train_acc_ema', 'train_error_ema',
        'train_class_loss', 'train_info_loss', 'train_total_loss'
        ]
book_keeper = {key: [] for key in keys}

iterations = 0
epoch = 0

# %% [markdown]
# ### Train loop

# %%
model.train()
model_ema.model.train()

for e in range(EPOCHS):
    total_num = 0
    epoch_iterations = 0
    epoch_class_loss = 0
    epoch_info_loss = 0
    epoch_total_loss = 0
    epoch_izy_bound = 0
    epoch_izx_bound = 0
    epoch_correct = 0
    correct = 0

    for idx, (images, labels) in enumerate(train_loader):
        iterations += 1

        x = images.to(device)
        y = labels.to(device)
        (mu, std), logit = model(x)

        class_loss = F.cross_entropy(logit, y).div(math.log(2)) # div(log(2)) -> transfer to bits
        info_loss = -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum(1).mean().div(math.log(2))
        total_loss = class_loss + BETA * info_loss

        izy_bound = math.log(10, 2) - class_loss
        izx_bound = info_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # A secondary smoothed network for comparison
        model_ema.update(model.state_dict())

        prediction = F.softmax(logit, dim=1).max(1)[1]
        accuracy = torch.eq(prediction, y).float().mean()

        # TODO: change this to MC sampling 
        avg_accuracy = torch.zeros(accuracy.size()).to(device)

        # book keeping
        epoch_class_loss += class_loss
        info_loss += info_loss
        total_loss += total_loss
        correct += torch.eq(prediction, y).float().sum()
        total_num += y.size(0)
        epoch_iterations += 1

        if (iterations % 100 == 0):
            print('i:{} IZY:{:.2f} IZX:{:.2f}'
                    .format(idx+1, izy_bound.data.item(), izx_bound.data.item()), end=' ')
            print('acc:{:.4f} avg_acc:{:.4f}'
                    .format(accuracy.data.item(), avg_accuracy.data.item()), end=' ')
            print('err:{:.4f} avg_err:{:.4f}'
                    .format(1-accuracy.data.item(), 1-avg_accuracy.data.item()))

    if (e % 2) == 0 and (e != 0):
        scheduler.step()

    accuracy_ = correct / total_num
    izy_bound /= epoch_iterations
    izx_bound /= total_num
    class_loss /= total_num
    info_loss /= total_num
    total_loss /= total_num

    book_keeper['train_izx'].append(izx_bound.data.item())
    book_keeper['train_izy'].append(izy_bound.data.item())
    book_keeper['train_acc'].append(accuracy_.data.item())
    book_keeper['train_error'].append(1 - accuracy_.data.item())
    book_keeper['train_class_loss'].append(class_loss.data.item())
    book_keeper['train_info_loss'].append(info_loss.data.item())
    book_keeper['train_total_loss'].append(total_loss.data.item())

    evaluate(model, model_ema)

print("----- Training complete -----")
# Out:
# i:100 IZY:2.76 IZX:887.28 acc:0.8700 avg_acc:0.0000 err:0.1300 avg_err:1.0000
# i:200 IZY:2.64 IZX:626.83 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# i:300 IZY:3.02 IZX:475.53 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:400 IZY:2.97 IZX:417.49 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:500 IZY:2.59 IZX:443.82 acc:0.8800 avg_acc:0.0000 err:0.1200 avg_err:1.0000
# i:600 IZY:2.97 IZX:352.20 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# [TEST RESULT - regular]
# e:0 IZY:3.03 IZX:162.86 acc:0.9374 avg_acc:0.0000 err:0.0626 avg_erra:1.0000
# [TEST RESULT - ema]
# e:0 IZY:2.18 IZX:1302.78 acc:0.7727 avg_acc:0.0000 err:0.2273 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:2.98 IZX:312.33 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:200 IZY:3.08 IZX:292.63 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:300 IZY:2.76 IZX:268.25 acc:0.8500 avg_acc:0.0000 err:0.1500 avg_err:1.0000
# i:400 IZY:3.16 IZX:255.31 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.18 IZX:265.26 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:600 IZY:3.07 IZX:271.47 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:1 IZY:3.12 IZX:128.29 acc:0.9560 avg_acc:0.0000 err:0.0440 avg_erra:1.0000
# [TEST RESULT - ema]
# e:1 IZY:3.00 IZX:819.04 acc:0.9445 avg_acc:0.0000 err:0.0555 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.19 IZX:246.12 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.18 IZX:212.28 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.23 IZX:223.67 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.21 IZX:218.65 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.15 IZX:206.82 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:600 IZY:3.19 IZX:222.43 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:2 IZY:3.16 IZX:101.93 acc:0.9634 avg_acc:0.0000 err:0.0366 avg_erra:1.0000
# [TEST RESULT - ema]
# e:2 IZY:3.15 IZX:466.31 acc:0.9647 avg_acc:0.0000 err:0.0353 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.20 IZX:193.04 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:200 IZY:3.15 IZX:212.56 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:300 IZY:3.17 IZX:201.95 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:400 IZY:3.13 IZX:210.41 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.20 IZX:210.58 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.22 IZX:179.25 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:3 IZY:3.16 IZX:92.02 acc:0.9661 avg_acc:0.0000 err:0.0339 avg_erra:1.0000
# [TEST RESULT - ema]
# e:3 IZY:3.19 IZX:265.75 acc:0.9699 avg_acc:0.0000 err:0.0301 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.31 IZX:193.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.27 IZX:187.47 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.23 IZX:179.95 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.26 IZX:199.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.21 IZX:195.77 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.27 IZX:198.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:4 IZY:3.18 IZX:88.15 acc:0.9691 avg_acc:0.0000 err:0.0309 avg_erra:1.0000
# [TEST RESULT - ema]
# e:4 IZY:3.20 IZX:167.53 acc:0.9736 avg_acc:0.0000 err:0.0264 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.27 IZX:171.74 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.27 IZX:156.98 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.28 IZX:188.22 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.30 IZX:166.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.28 IZX:167.48 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.28 IZX:167.14 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:5 IZY:3.18 IZX:83.83 acc:0.9697 avg_acc:0.0000 err:0.0303 avg_erra:1.0000
# [TEST RESULT - ema]
# e:5 IZY:3.20 IZX:120.90 acc:0.9734 avg_acc:0.0000 err:0.0266 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# i:100 IZY:3.29 IZX:166.90 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.29 IZX:161.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.20 IZX:152.24 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.25 IZX:153.25 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.30 IZX:154.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.29 IZX:163.70 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:6 IZY:3.19 IZX:79.02 acc:0.9722 avg_acc:0.0000 err:0.0278 avg_erra:1.0000
# [TEST RESULT - ema]
# e:6 IZY:3.21 IZX:99.05 acc:0.9741 avg_acc:0.0000 err:0.0259 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.25 IZX:158.33 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.30 IZX:159.39 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.29 IZX:152.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.26 IZX:148.10 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.24 IZX:161.97 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.28 IZX:164.18 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:7 IZY:3.19 IZX:77.61 acc:0.9728 avg_acc:0.0000 err:0.0272 avg_erra:1.0000
# [TEST RESULT - ema]
# e:7 IZY:3.21 IZX:87.23 acc:0.9760 avg_acc:0.0000 err:0.0240 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.28 IZX:160.71 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.25 IZX:158.34 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.24 IZX:142.45 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.30 IZX:135.89 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:133.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.26 IZX:131.80 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:8 IZY:3.18 IZX:68.76 acc:0.9726 avg_acc:0.0000 err:0.0274 avg_erra:1.0000
# [TEST RESULT - ema]
# e:8 IZY:3.21 IZX:79.44 acc:0.9753 avg_acc:0.0000 err:0.0247 avg_erra:1.0000
#
# i:100 IZY:3.21 IZX:141.21 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.28 IZX:135.91 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.30 IZX:127.18 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.31 IZX:132.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.25 IZX:129.20 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.27 IZX:141.96 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:9 IZY:3.20 IZX:72.14 acc:0.9762 avg_acc:0.0000 err:0.0238 avg_erra:1.0000
# [TEST RESULT - ema]
# e:9 IZY:3.22 IZX:74.16 acc:0.9780 avg_acc:0.0000 err:0.0220 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.28 IZX:126.45 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:127.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:125.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.19 IZX:136.99 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.27 IZX:130.54 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.29 IZX:135.50 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:10 IZY:3.19 IZX:66.61 acc:0.9727 avg_acc:0.0000 err:0.0273 avg_erra:1.0000
# [TEST RESULT - ema]
# e:10 IZY:3.21 IZX:70.70 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.28 IZX:130.87 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:134.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:132.72 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:127.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:127.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.24 IZX:140.98 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:11 IZY:3.19 IZX:66.98 acc:0.9720 avg_acc:0.0000 err:0.0280 avg_erra:1.0000
# [TEST RESULT - ema]
# e:11 IZY:3.22 IZX:67.72 acc:0.9783 avg_acc:0.0000 err:0.0217 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.31 IZX:121.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.28 IZX:135.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:130.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:130.78 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.27 IZX:126.55 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.30 IZX:125.95 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:12 IZY:3.19 IZX:63.43 acc:0.9739 avg_acc:0.0000 err:0.0261 avg_erra:1.0000
# [TEST RESULT - ema]
# e:12 IZY:3.21 IZX:65.52 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.28 IZX:122.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.30 IZX:126.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:130.92 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:110.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.29 IZX:118.17 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.31 IZX:116.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:13 IZY:3.20 IZX:57.65 acc:0.9759 avg_acc:0.0000 err:0.0241 avg_erra:1.0000
# [TEST RESULT - ema]
# e:13 IZY:3.21 IZX:63.06 acc:0.9780 avg_acc:0.0000 err:0.0220 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:125.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:114.95 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:115.31 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:115.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.27 IZX:121.19 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:118.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:14 IZY:3.19 IZX:59.28 acc:0.9729 avg_acc:0.0000 err:0.0271 avg_erra:1.0000
# [TEST RESULT - ema]
# e:14 IZY:3.22 IZX:61.07 acc:0.9793 avg_acc:0.0000 err:0.0207 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.31 IZX:120.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:117.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:126.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:112.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.24 IZX:110.18 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.32 IZX:129.29 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:15 IZY:3.20 IZX:62.96 acc:0.9762 avg_acc:0.0000 err:0.0238 avg_erra:1.0000
# [TEST RESULT - ema]
# e:15 IZY:3.22 IZX:59.19 acc:0.9782 avg_acc:0.0000 err:0.0218 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:111.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:107.66 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:112.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:108.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.29 IZX:112.24 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:115.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:16 IZY:3.19 IZX:56.14 acc:0.9745 avg_acc:0.0000 err:0.0255 avg_erra:1.0000
# [TEST RESULT - ema]
# e:16 IZY:3.21 IZX:57.20 acc:0.9801 avg_acc:0.0000 err:0.0199 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.32 IZX:109.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.28 IZX:103.85 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.28 IZX:102.57 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:112.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:110.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:110.79 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:17 IZY:3.21 IZX:52.88 acc:0.9775 avg_acc:0.0000 err:0.0225 avg_erra:1.0000
# [TEST RESULT - ema]
# e:17 IZY:3.21 IZX:55.70 acc:0.9784 avg_acc:0.0000 err:0.0216 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# i:100 IZY:3.30 IZX:99.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:100.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.27 IZX:105.99 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.27 IZX:103.74 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.32 IZX:100.20 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:104.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:18 IZY:3.21 IZX:51.79 acc:0.9767 avg_acc:0.0000 err:0.0233 avg_erra:1.0000
# [TEST RESULT - ema]
# e:18 IZY:3.22 IZX:54.13 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:101.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:95.89 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:111.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:99.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:99.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:103.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:19 IZY:3.19 IZX:50.42 acc:0.9752 avg_acc:0.0000 err:0.0248 avg_erra:1.0000
# [TEST RESULT - ema]
# e:19 IZY:3.21 IZX:52.91 acc:0.9795 avg_acc:0.0000 err:0.0205 avg_erra:1.0000
#
# i:100 IZY:3.29 IZX:100.24 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:103.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:104.39 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.31 IZX:96.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:102.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.29 IZX:105.76 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:20 IZY:3.19 IZX:51.98 acc:0.9746 avg_acc:0.0000 err:0.0254 avg_erra:1.0000
# [TEST RESULT - ema]
# e:20 IZY:3.21 IZX:52.05 acc:0.9801 avg_acc:0.0000 err:0.0199 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:97.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:100.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:88.45 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:96.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:97.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:101.93 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:21 IZY:3.20 IZX:48.80 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:21 IZY:3.21 IZX:50.69 acc:0.9794 avg_acc:0.0000 err:0.0206 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:92.27 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:98.24 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:101.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:98.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:99.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.28 IZX:104.04 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:22 IZY:3.20 IZX:51.35 acc:0.9780 avg_acc:0.0000 err:0.0220 avg_erra:1.0000
# [TEST RESULT - ema]
# e:22 IZY:3.21 IZX:49.74 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# i:100 IZY:3.32 IZX:93.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:96.13 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:93.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:92.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.29 IZX:95.74 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.31 IZX:93.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:23 IZY:3.20 IZX:48.07 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
# [TEST RESULT - ema]
# e:23 IZY:3.21 IZX:48.89 acc:0.9795 avg_acc:0.0000 err:0.0205 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:95.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:87.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:90.31 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:94.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:101.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:95.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:24 IZY:3.20 IZX:47.85 acc:0.9792 avg_acc:0.0000 err:0.0208 avg_erra:1.0000
# [TEST RESULT - ema]
# e:24 IZY:3.21 IZX:47.75 acc:0.9787 avg_acc:0.0000 err:0.0213 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# i:100 IZY:3.31 IZX:82.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:93.04 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:88.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.30 IZX:97.85 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:97.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:94.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:25 IZY:3.19 IZX:48.03 acc:0.9782 avg_acc:0.0000 err:0.0218 avg_erra:1.0000
# [TEST RESULT - ema]
# e:25 IZY:3.22 IZX:46.74 acc:0.9799 avg_acc:0.0000 err:0.0201 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:88.98 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:100.00 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:90.79 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:93.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:94.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:88.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:26 IZY:3.20 IZX:45.85 acc:0.9758 avg_acc:0.0000 err:0.0242 avg_erra:1.0000
# [TEST RESULT - ema]
# e:26 IZY:3.21 IZX:45.79 acc:0.9797 avg_acc:0.0000 err:0.0203 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:83.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:85.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:91.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:88.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:86.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:85.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:27 IZY:3.20 IZX:43.89 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
# [TEST RESULT - ema]
# e:27 IZY:3.21 IZX:44.90 acc:0.9794 avg_acc:0.0000 err:0.0206 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:81.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:87.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:79.32 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:81.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:83.43 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:87.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:28 IZY:3.20 IZX:42.68 acc:0.9776 avg_acc:0.0000 err:0.0224 avg_erra:1.0000
# [TEST RESULT - ema]
# e:28 IZY:3.21 IZX:44.17 acc:0.9798 avg_acc:0.0000 err:0.0202 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:91.88 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:86.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:85.61 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:80.93 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:96.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:91.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:29 IZY:3.19 IZX:43.59 acc:0.9778 avg_acc:0.0000 err:0.0222 avg_erra:1.0000
# [TEST RESULT - ema]
# e:29 IZY:3.21 IZX:44.16 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:83.55 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:92.92 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:81.75 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:86.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:87.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:83.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:30 IZY:3.19 IZX:42.08 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:30 IZY:3.22 IZX:43.88 acc:0.9819 avg_acc:0.0000 err:0.0181 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.32 IZX:83.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:88.05 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:79.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:84.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:80.04 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:81.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:31 IZY:3.20 IZX:41.29 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
# [TEST RESULT - ema]
# e:31 IZY:3.21 IZX:43.17 acc:0.9821 avg_acc:0.0000 err:0.0179 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model_ema.h5
# i:100 IZY:3.31 IZX:76.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:96.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:89.16 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.31 IZX:86.21 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:74.30 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:80.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:32 IZY:3.19 IZX:39.92 acc:0.9770 avg_acc:0.0000 err:0.0230 avg_erra:1.0000
# [TEST RESULT - ema]
# e:32 IZY:3.21 IZX:42.14 acc:0.9807 avg_acc:0.0000 err:0.0193 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:87.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:79.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:83.02 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:78.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:82.02 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.29 IZX:78.16 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:33 IZY:3.20 IZX:40.43 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
# [TEST RESULT - ema]
# e:33 IZY:3.20 IZX:41.11 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:76.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:81.53 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:76.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.30 IZX:79.18 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:84.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:83.89 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:34 IZY:3.19 IZX:40.07 acc:0.9762 avg_acc:0.0000 err:0.0238 avg_erra:1.0000
# [TEST RESULT - ema]
# e:34 IZY:3.20 IZX:40.81 acc:0.9798 avg_acc:0.0000 err:0.0202 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:82.93 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:73.66 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.30 IZX:81.53 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.30 IZX:78.93 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:79.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:76.49 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:35 IZY:3.20 IZX:40.35 acc:0.9756 avg_acc:0.0000 err:0.0244 avg_erra:1.0000
# [TEST RESULT - ema]
# e:35 IZY:3.21 IZX:40.58 acc:0.9809 avg_acc:0.0000 err:0.0191 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:74.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:84.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:78.95 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:81.72 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:77.20 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:75.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:36 IZY:3.20 IZX:36.90 acc:0.9776 avg_acc:0.0000 err:0.0224 avg_erra:1.0000
# [TEST RESULT - ema]
# e:36 IZY:3.21 IZX:40.02 acc:0.9786 avg_acc:0.0000 err:0.0214 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:82.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:76.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:77.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:76.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:76.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.27 IZX:74.51 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:37 IZY:3.20 IZX:40.02 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
# [TEST RESULT - ema]
# e:37 IZY:3.21 IZX:39.54 acc:0.9811 avg_acc:0.0000 err:0.0189 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:75.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:75.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:76.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.27 IZX:77.23 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:79.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:75.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:38 IZY:3.19 IZX:37.35 acc:0.9755 avg_acc:0.0000 err:0.0245 avg_erra:1.0000
# [TEST RESULT - ema]
# e:38 IZY:3.21 IZX:39.47 acc:0.9801 avg_acc:0.0000 err:0.0199 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:74.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:72.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:69.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:75.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:73.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:78.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:39 IZY:3.20 IZX:38.85 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
# [TEST RESULT - ema]
# e:39 IZY:3.21 IZX:38.70 acc:0.9791 avg_acc:0.0000 err:0.0209 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:79.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:77.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:75.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:77.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:81.15 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:75.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:40 IZY:3.18 IZX:37.64 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:40 IZY:3.21 IZX:38.36 acc:0.9805 avg_acc:0.0000 err:0.0195 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:72.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:76.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:71.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:75.50 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:75.56 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:71.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:41 IZY:3.19 IZX:38.28 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
# [TEST RESULT - ema]
# e:41 IZY:3.21 IZX:38.43 acc:0.9792 avg_acc:0.0000 err:0.0208 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:72.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:72.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:72.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:69.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:80.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:78.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:42 IZY:3.19 IZX:37.31 acc:0.9776 avg_acc:0.0000 err:0.0224 avg_erra:1.0000
# [TEST RESULT - ema]
# e:42 IZY:3.21 IZX:37.99 acc:0.9795 avg_acc:0.0000 err:0.0205 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:71.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:73.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:73.02 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:67.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:72.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:77.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:43 IZY:3.19 IZX:41.26 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:43 IZY:3.21 IZX:37.30 acc:0.9802 avg_acc:0.0000 err:0.0198 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:68.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:72.80 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:70.04 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:74.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:70.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:77.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:44 IZY:3.19 IZX:36.62 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
# [TEST RESULT - ema]
# e:44 IZY:3.21 IZX:36.95 acc:0.9807 avg_acc:0.0000 err:0.0193 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:70.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:74.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:69.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:74.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:71.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:70.52 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:45 IZY:3.19 IZX:34.68 acc:0.9758 avg_acc:0.0000 err:0.0242 avg_erra:1.0000
# [TEST RESULT - ema]
# e:45 IZY:3.21 IZX:36.61 acc:0.9791 avg_acc:0.0000 err:0.0209 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:69.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:73.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:72.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:74.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:66.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:69.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:46 IZY:3.19 IZX:35.27 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
# [TEST RESULT - ema]
# e:46 IZY:3.21 IZX:36.29 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:72.56 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:72.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:71.88 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:67.02 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:72.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:71.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:47 IZY:3.18 IZX:37.01 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:47 IZY:3.20 IZX:35.82 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:71.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:70.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:67.20 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.50 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:71.54 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:73.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:48 IZY:3.19 IZX:37.43 acc:0.9777 avg_acc:0.0000 err:0.0223 avg_erra:1.0000
# [TEST RESULT - ema]
# e:48 IZY:3.20 IZX:35.49 acc:0.9792 avg_acc:0.0000 err:0.0208 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:68.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:68.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:69.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:73.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:62.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:49 IZY:3.18 IZX:33.72 acc:0.9757 avg_acc:0.0000 err:0.0243 avg_erra:1.0000
# [TEST RESULT - ema]
# e:49 IZY:3.21 IZX:35.29 acc:0.9802 avg_acc:0.0000 err:0.0198 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:68.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:72.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:66.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:75.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:69.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:68.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:50 IZY:3.19 IZX:34.79 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:50 IZY:3.20 IZX:35.14 acc:0.9779 avg_acc:0.0000 err:0.0221 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:75.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:75.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:68.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:74.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:51 IZY:3.17 IZX:36.81 acc:0.9761 avg_acc:0.0000 err:0.0239 avg_erra:1.0000
# [TEST RESULT - ema]
# e:51 IZY:3.20 IZX:35.23 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:71.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:69.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:67.00 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:69.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:66.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:71.37 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:52 IZY:3.19 IZX:35.41 acc:0.9778 avg_acc:0.0000 err:0.0222 avg_erra:1.0000
# [TEST RESULT - ema]
# e:52 IZY:3.21 IZX:34.95 acc:0.9802 avg_acc:0.0000 err:0.0198 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:65.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:70.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:66.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:71.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:65.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:64.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:53 IZY:3.19 IZX:33.10 acc:0.9775 avg_acc:0.0000 err:0.0225 avg_erra:1.0000
# [TEST RESULT - ema]
# e:53 IZY:3.21 IZX:34.57 acc:0.9796 avg_acc:0.0000 err:0.0204 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:64.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:67.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:69.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.80 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:68.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:65.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:54 IZY:3.20 IZX:34.06 acc:0.9785 avg_acc:0.0000 err:0.0215 avg_erra:1.0000
# [TEST RESULT - ema]
# e:54 IZY:3.21 IZX:34.43 acc:0.9803 avg_acc:0.0000 err:0.0197 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:64.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:65.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:65.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:68.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:64.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:67.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:55 IZY:3.19 IZX:33.17 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:55 IZY:3.20 IZX:34.07 acc:0.9805 avg_acc:0.0000 err:0.0195 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:69.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:66.92 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:67.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:64.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:56 IZY:3.18 IZX:32.33 acc:0.9771 avg_acc:0.0000 err:0.0229 avg_erra:1.0000
# [TEST RESULT - ema]
# e:56 IZY:3.20 IZX:33.71 acc:0.9799 avg_acc:0.0000 err:0.0201 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:66.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:66.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:65.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:62.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:68.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:63.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:57 IZY:3.19 IZX:31.95 acc:0.9772 avg_acc:0.0000 err:0.0228 avg_erra:1.0000
# [TEST RESULT - ema]
# e:57 IZY:3.20 IZX:33.40 acc:0.9787 avg_acc:0.0000 err:0.0213 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:68.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:69.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:69.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:63.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:66.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:58 IZY:3.18 IZX:32.10 acc:0.9786 avg_acc:0.0000 err:0.0214 avg_erra:1.0000
# [TEST RESULT - ema]
# e:58 IZY:3.20 IZX:33.39 acc:0.9779 avg_acc:0.0000 err:0.0221 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:67.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.24 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:64.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:66.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:65.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:59 IZY:3.19 IZX:32.99 acc:0.9794 avg_acc:0.0000 err:0.0206 avg_erra:1.0000
# [TEST RESULT - ema]
# e:59 IZY:3.19 IZX:33.04 acc:0.9807 avg_acc:0.0000 err:0.0193 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/mnist_model.h5
# i:100 IZY:3.29 IZX:67.41 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:66.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:69.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:64.23 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:69.84 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:60 IZY:3.18 IZX:34.72 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:60 IZY:3.19 IZX:33.12 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:62.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:66.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:66.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.72 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:66.70 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.31 IZX:68.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:61 IZY:3.19 IZX:34.75 acc:0.9788 avg_acc:0.0000 err:0.0212 avg_erra:1.0000
# [TEST RESULT - ema]
# e:61 IZY:3.21 IZX:33.16 acc:0.9803 avg_acc:0.0000 err:0.0197 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:71.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:67.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:62.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:64.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:65.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:61.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:62 IZY:3.18 IZX:31.70 acc:0.9772 avg_acc:0.0000 err:0.0228 avg_erra:1.0000
# [TEST RESULT - ema]
# e:62 IZY:3.20 IZX:32.83 acc:0.9806 avg_acc:0.0000 err:0.0194 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:65.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:61.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:68.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:62.37 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:68.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:63 IZY:3.19 IZX:33.69 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
# [TEST RESULT - ema]
# e:63 IZY:3.20 IZX:32.57 acc:0.9787 avg_acc:0.0000 err:0.0213 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.62 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:63.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:62.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:69.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:64 IZY:3.19 IZX:32.49 acc:0.9775 avg_acc:0.0000 err:0.0225 avg_erra:1.0000
# [TEST RESULT - ema]
# e:64 IZY:3.20 IZX:32.43 acc:0.9794 avg_acc:0.0000 err:0.0206 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:66.95 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:64.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:60.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:65 IZY:3.18 IZX:31.03 acc:0.9778 avg_acc:0.0000 err:0.0222 avg_erra:1.0000
# [TEST RESULT - ema]
# e:65 IZY:3.20 IZX:32.08 acc:0.9793 avg_acc:0.0000 err:0.0207 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:62.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:61.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:61.23 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:63.27 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:66.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:66 IZY:3.17 IZX:32.86 acc:0.9754 avg_acc:0.0000 err:0.0246 avg_erra:1.0000
# [TEST RESULT - ema]
# e:66 IZY:3.18 IZX:32.00 acc:0.9787 avg_acc:0.0000 err:0.0213 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:66.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:61.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:62.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:68.89 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:59.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:67 IZY:3.19 IZX:31.50 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
# [TEST RESULT - ema]
# e:67 IZY:3.20 IZX:31.96 acc:0.9793 avg_acc:0.0000 err:0.0207 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:61.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:63.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:65.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:66.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:59.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:68 IZY:3.17 IZX:30.47 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:68 IZY:3.19 IZX:31.87 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
#
# ...
#
# i:100 IZY:3.32 IZX:49.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:52.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.85 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:176 IZY:3.19 IZX:25.45 acc:0.9771 avg_acc:0.0000 err:0.0229 avg_erra:1.0000
# [TEST RESULT - ema]
# e:176 IZY:3.18 IZX:25.81 acc:0.9769 avg_acc:0.0000 err:0.0231 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:51.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:48.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:51.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:51.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:177 IZY:3.18 IZX:25.85 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
# [TEST RESULT - ema]
# e:177 IZY:3.18 IZX:25.81 acc:0.9789 avg_acc:0.0000 err:0.0211 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:51.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:178 IZY:3.18 IZX:25.93 acc:0.9752 avg_acc:0.0000 err:0.0248 avg_erra:1.0000
# [TEST RESULT - ema]
# e:178 IZY:3.18 IZX:25.79 acc:0.9781 avg_acc:0.0000 err:0.0219 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:50.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.24 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:48.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:179 IZY:3.17 IZX:25.67 acc:0.9760 avg_acc:0.0000 err:0.0240 avg_erra:1.0000
# [TEST RESULT - ema]
# e:179 IZY:3.18 IZX:25.67 acc:0.9778 avg_acc:0.0000 err:0.0222 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.54 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:51.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:180 IZY:3.17 IZX:25.66 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:180 IZY:3.17 IZX:25.66 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:50.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:51.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:48.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:181 IZY:3.17 IZX:25.50 acc:0.9746 avg_acc:0.0000 err:0.0254 avg_erra:1.0000
# [TEST RESULT - ema]
# e:181 IZY:3.18 IZX:25.66 acc:0.9771 avg_acc:0.0000 err:0.0229 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:49.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:51.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.24 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:182 IZY:3.18 IZX:25.61 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
# [TEST RESULT - ema]
# e:182 IZY:3.18 IZX:25.67 acc:0.9782 avg_acc:0.0000 err:0.0218 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.88 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:49.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.80 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:51.09 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:51.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:183 IZY:3.17 IZX:25.80 acc:0.9763 avg_acc:0.0000 err:0.0237 avg_erra:1.0000
# [TEST RESULT - ema]
# e:183 IZY:3.19 IZX:25.71 acc:0.9786 avg_acc:0.0000 err:0.0214 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:51.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:51.27 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.92 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:48.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:48.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:184 IZY:3.18 IZX:25.25 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
# [TEST RESULT - ema]
# e:184 IZY:3.17 IZX:25.66 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.00 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:51.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:49.80 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:185 IZY:3.18 IZX:25.64 acc:0.9784 avg_acc:0.0000 err:0.0216 avg_erra:1.0000
# [TEST RESULT - ema]
# e:185 IZY:3.18 IZX:25.63 acc:0.9764 avg_acc:0.0000 err:0.0236 avg_erra:1.0000
#
# i:100 IZY:3.27 IZX:48.00 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:49.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:53.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:186 IZY:3.17 IZX:25.95 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:186 IZY:3.17 IZX:25.69 acc:0.9777 avg_acc:0.0000 err:0.0223 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:48.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:51.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:49.20 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:51.95 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:187 IZY:3.18 IZX:25.71 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:187 IZY:3.18 IZX:25.64 acc:0.9777 avg_acc:0.0000 err:0.0223 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:48.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:48.42 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:52.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:49.84 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:188 IZY:3.16 IZX:25.45 acc:0.9766 avg_acc:0.0000 err:0.0234 avg_erra:1.0000
# [TEST RESULT - ema]
# e:188 IZY:3.17 IZX:25.57 acc:0.9762 avg_acc:0.0000 err:0.0238 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:50.58 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:51.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:50.79 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:51.27 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:189 IZY:3.18 IZX:25.69 acc:0.9766 avg_acc:0.0000 err:0.0234 avg_erra:1.0000
# [TEST RESULT - ema]
# e:189 IZY:3.18 IZX:25.62 acc:0.9777 avg_acc:0.0000 err:0.0223 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:50.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:49.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:52.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:190 IZY:3.18 IZX:25.55 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
# [TEST RESULT - ema]
# e:190 IZY:3.17 IZX:25.60 acc:0.9752 avg_acc:0.0000 err:0.0248 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:51.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.54 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:52.11 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:48.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:191 IZY:3.17 IZX:25.35 acc:0.9760 avg_acc:0.0000 err:0.0240 avg_erra:1.0000
# [TEST RESULT - ema]
# e:191 IZY:3.18 IZX:25.56 acc:0.9790 avg_acc:0.0000 err:0.0210 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:50.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:50.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:51.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.28 IZX:50.82 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:192 IZY:3.17 IZX:26.23 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
# [TEST RESULT - ema]
# e:192 IZY:3.18 IZX:25.62 acc:0.9774 avg_acc:0.0000 err:0.0226 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:51.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:48.47 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:51.52 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.66 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:193 IZY:3.17 IZX:25.32 acc:0.9765 avg_acc:0.0000 err:0.0235 avg_erra:1.0000
# [TEST RESULT - ema]
# e:193 IZY:3.17 IZX:25.64 acc:0.9773 avg_acc:0.0000 err:0.0227 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:49.63 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:52.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:50.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.64 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:194 IZY:3.18 IZX:25.76 acc:0.9760 avg_acc:0.0000 err:0.0240 avg_erra:1.0000
# [TEST RESULT - ema]
# e:194 IZY:3.18 IZX:25.56 acc:0.9767 avg_acc:0.0000 err:0.0233 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:49.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:49.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:50.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.30 IZX:48.02 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:195 IZY:3.17 IZX:25.41 acc:0.9766 avg_acc:0.0000 err:0.0234 avg_erra:1.0000
# [TEST RESULT - ema]
# e:195 IZY:3.18 IZX:25.49 acc:0.9770 avg_acc:0.0000 err:0.0230 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:51.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:49.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.00 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:196 IZY:3.18 IZX:25.41 acc:0.9776 avg_acc:0.0000 err:0.0224 avg_erra:1.0000
# [TEST RESULT - ema]
# e:196 IZY:3.16 IZX:25.46 acc:0.9768 avg_acc:0.0000 err:0.0232 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:50.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.27 IZX:48.60 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:49.30 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:51.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:51.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:49.52 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:197 IZY:3.17 IZX:25.59 acc:0.9760 avg_acc:0.0000 err:0.0240 avg_erra:1.0000
# [TEST RESULT - ema]
# e:197 IZY:3.18 IZX:25.49 acc:0.9782 avg_acc:0.0000 err:0.0218 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:50.76 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:50.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:49.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:47.23 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:198 IZY:3.18 IZX:25.33 acc:0.9785 avg_acc:0.0000 err:0.0215 avg_erra:1.0000
# [TEST RESULT - ema]
# e:198 IZY:3.17 IZX:25.50 acc:0.9762 avg_acc:0.0000 err:0.0238 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:49.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:48.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:49.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:49.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:50.08 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:50.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:199 IZY:3.19 IZX:25.47 acc:0.9780 avg_acc:0.0000 err:0.0220 avg_erra:1.0000
# [TEST RESULT - ema]
# e:199 IZY:3.19 IZX:25.44 acc:0.9796 avg_acc:0.0000 err:0.0204 avg_erra:1.0000
#
# ----- Training complete -----

# %%
with open(PICKLE_SAVE_PATH, 'wb') as f:
    pickle.dump(book_keeper, f)
