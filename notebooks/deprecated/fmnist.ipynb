# %%
import numpy as np
import torch
import math
import os
import pickle
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from torchvision import transforms
from pathlib import Path
import torch.nn.init as init
from torchvision.datasets import FashionMNIST

# %%
DATA_DIR = '/content/drive/MyDrive/AML_project/datasets/FMNIST_DATASET'
SEED = 42
K = 256
BATCH_SIZE = 100
LR = 1e-4 # learning rate
BETA = 1e-3 # rate distortion hyperparam
BETA_DECAY = 0.999 # EMA exponential decay
SAVE_DIR = '/content/drive/MyDrive/AML_project'
MODEL_SAVE_PATH = '/content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5'
EMA_SAVE_PATH = '/content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5'
PICKLE_SAVE_PATH = '/content/drive/MyDrive/AML_project/pickles/fmnist_stats.pkl'
LOAD_MODEL = False
MC_SAMPLE_SIZE = 12
EPOCHS = 200 # in the paprt they did 200 epochs

# %%
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
if os.path.isdir(DATA_DIR):
    train_data = FashionMNIST(root=DATA_DIR, train=True, transform=transforms.ToTensor())
    test_data = FashionMNIST(root=DATA_DIR, train=False, transform=transforms.ToTensor())
else:
    os.mkdir(DATA_DIR)
    train_data = FashionMNIST(root=DATA_DIR, train=True, download=True, transform=transforms.ToTensor())
    test_data = FashionMNIST(root=DATA_DIR, train=False, download=True, transform=transforms.ToTensor())

fmnist_classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
train_loader = DataLoader(train_data,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=1,
                          drop_last=True)

test_loader = DataLoader(test_data,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=1,
                         drop_last=False)

# %%
def reparametrize(mu, std):
    """
    Performs reparameterization trick z = mu + epsilon * std
    Where epsilon~N(0,1)
    """
    mu = mu.expand(1, *mu.size())
    std = std.expand(1, *std.size())
    eps = torch.normal(0, 1, size=std.size()).to(device)
    return mu + eps * std

def evaluate(model, model_ema):
    model.eval()
    model_ema.model.eval()
    total_iterations = 0

    class_loss = 0
    info_loss = 0
    total_loss = 0
    izy_bound = 0
    izx_bound = 0
    correct = 0
    avg_correct = 0

    class_loss_ema = 0
    info_loss_ema = 0
    total_loss_ema = 0
    izy_bound_ema = 0
    izx_bound_ema = 0
    correct_ema = 0
    avg_correct_ema = 0
    total_num = 0

    for idx, (images, labels) in enumerate(test_loader):

        x = images.to(device)
        y = labels.to(device)

        (mu, std), logit = model(x)
        (mu_ema, std_ema), logit_ema = model_ema.model(x)

        class_loss += F.cross_entropy(logit, y).div(math.log(2))
        info_loss += -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum().div(math.log(2))
        total_loss += class_loss + BETA * info_loss

        # TODO: check if size_average=False is needed here
        class_loss_ema += F.cross_entropy(logit_ema, y).div(math.log(2)) # reduction='sum'
        info_loss_ema += -0.5 * (1 + 2 * std_ema.log() - mu_ema.pow(2) - std_ema.pow(2)).sum().div(math.log(2))
        total_loss_ema += class_loss_ema + BETA * info_loss_ema

        total_num += y.size(0)
        total_iterations += 1

        # the math.log(10,2) is the entropy of the uniform RV for 10 examples in bits
        # (not expectation cause we assume it's unifrom).
        # This is negative in sign because we switch from a loss to a gain function
        izy_bound += math.log(10,2) - F.cross_entropy(logit, y).div(math.log(2))
        izx_bound += -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum().div(math.log(2))

        izy_bound_ema += math.log(10,2) - F.cross_entropy(logit_ema, y).div(math.log(2)) # reduction='sum'
        izx_bound_ema += -0.5 * (1 + 2 * std_ema.log() - mu_ema.pow(2) - std_ema.pow(2)).sum().div(math.log(2))

        prediction = F.softmax(logit, dim=1).max(1)[1]
        correct += torch.eq(prediction, y).float().sum()

        prediction_ema = F.softmax(logit_ema, dim=1).max(1)[1]
        correct_ema += torch.eq(prediction_ema, y).float().sum()

        # TODO: add MC logic
        avg_correct = torch.zeros(correct.size()).to(device)
        avg_correct_ema = torch.zeros(correct_ema.size()).to(device)

    accuracy = correct / total_num
    avg_accuracy = avg_correct / total_num

    accuracy_ema = correct_ema / total_num
    avg_accuracy_ema = avg_correct_ema / total_num

    izy_bound /= total_iterations
    izx_bound /= total_num
    class_loss /= total_num
    info_loss /= total_num
    total_loss /= total_num

    izy_bound_ema /= total_iterations
    izx_bound_ema /= total_num
    class_loss_ema /= total_num
    info_loss_ema /= total_num
    total_loss_ema /= total_num

    book_keeper['test_izx'].append(izx_bound.data.item())
    book_keeper['test_izy'].append(izy_bound.data.item())
    book_keeper['test_acc'].append(accuracy.data.item())
    book_keeper['test_error'].append(1 - accuracy.data.item())
    book_keeper['test_class_loss'].append(class_loss.data.item())
    book_keeper['test_info_loss'].append(info_loss.data.item())
    book_keeper['test_total_loss'].append(total_loss.data.item())
    book_keeper['test_izx_ema'].append(izx_bound_ema.data.item())
    book_keeper['test_izy_ema'].append(izy_bound_ema.data.item())
    book_keeper['test_acc_ema'].append(accuracy_ema.data.item())
    book_keeper['test_error_ema'].append(1 - accuracy_ema.data.item())
    book_keeper['test_class_loss_ema'].append(class_loss_ema.data.item())
    book_keeper['test_info_loss_ema'].append(info_loss_ema.data.item())
    book_keeper['test_total_loss_ema'].append(total_loss_ema.data.item())

    print('[TEST RESULT - regular]')
    print('e:{} IZY:{:.2f} IZX:{:.2f}'
            .format(e, izy_bound.data.item(), izx_bound.data.item()), end=' ')
    print('acc:{:.4f} avg_acc:{:.4f}'
            .format(accuracy.data.item(), avg_accuracy.data.item()), end=' ')
    print('err:{:.4f} avg_erra:{:.4f}'
            .format(1 - accuracy.data.item(), 1 - avg_accuracy.data.item()))
    
    print('[TEST RESULT - ema]')
    print('e:{} IZY:{:.2f} IZX:{:.2f}'
            .format(e, izy_bound_ema.data.item(), izx_bound_ema.data.item()), end=' ')
    print('acc:{:.4f} avg_acc:{:.4f}'
            .format(accuracy_ema.data.item(), avg_accuracy_ema.data.item()), end=' ')
    print('err:{:.4f} avg_erra:{:.4f}'
            .format(1 - accuracy_ema.data.item(), 1 - avg_accuracy_ema.data.item()))
    print()

    if history['acc'] < accuracy.data.item():
        history['acc'] = accuracy.data.item()
        history['avg_acc'] = avg_accuracy.data.item()
        history['class_loss'] = class_loss.data.item()
        history['info_loss'] = info_loss.data.item()
        history['total_loss'] = total_loss.data.item()
        history['epoch'] = e
        history['iter'] = iterations
        torch.save(model, MODEL_SAVE_PATH)
        print('Saved model to {}'.format(MODEL_SAVE_PATH))
    
    if history_ema['acc'] < accuracy_ema.data.item():
        history_ema['acc'] = accuracy_ema.data.item()
        history_ema['avg_acc'] = avg_accuracy_ema.data.item()
        history_ema['class_loss'] = class_loss_ema.data.item()
        history_ema['info_loss'] = info_loss_ema.data.item()
        history_ema['total_loss'] = total_loss_ema.data.item()
        history_ema['epoch'] = e
        history_ema['iter'] = iterations
        torch.save(model_ema, EMA_SAVE_PATH)
        print('Saved model to {}'.format(EMA_SAVE_PATH))

    model.train()
    model_ema.model.train()

# %%
class MNIST_IB_VAE(nn.Module):
    """
    Direct implementation of the paper's MNIST net
    Only one shot eval (no MC) - work well for beta <= 1e-3
    """
    def __init__(self, k=K):
        super(MNIST_IB_VAE, self).__init__()
        self.k = k

        self.encoder = nn.Sequential(
            nn.Linear(784, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 1024),
            nn.ReLU(True),
            nn.Linear(1024, 2 * self.k))

        self.decoder = nn.Sequential(
                nn.Linear(self.k, 10))

        # Xavier initialization
        for _, module in self._modules.items():
            for layer in module:
                if isinstance(layer, nn.Linear) or isinstance(layer, nn.Conv2d):
                            nn.init.xavier_uniform_(layer.weight, gain=nn.init.calculate_gain('relu'))
                            layer.bias.data.zero_()

    def forward(self, x):
        # squiwsh from shape (100,1,28,28) to (100,784)
        x = x.view(x.size(0),-1)
        z_params = self.encoder(x)
        mu = z_params[:, :self.k]
        # softplus transformation (soft relu) and a -5 bias is added as in the paper
        std = F.softplus(z_params[:, self.k:] - 5, beta=1)
        z = reparametrize(mu, std)
        logit = self.decoder(z)
        return (mu, std), logit[0]

class EMA_smoothning(object):
    """
    Performs exponential moving average smoothing on model updates as per
    Polyak & Juditsky, 1992.
    This will be used as a second network refference when evaluating.
    """
    def __init__(self, model, state_dict, beta_decay=0.999):
        self.model = model
        self.model.load_state_dict(state_dict, strict=True)
        self.beta_decay = beta_decay

    def update(self, new_state_dict):
        state_dict = self.model.state_dict()
        for key in state_dict.keys():
            state_dict[key] = (self.beta_decay) * state_dict[key] + (1 - self.beta_decay) * new_state_dict[key]
        self.model.load_state_dict(state_dict)

# %%
if LOAD_MODEL:
    model = torch.load(MODEL_SAVE_PATH)
else:
    model = MNIST_IB_VAE(k=K).to(device)

model_ema = EMA_smoothning(MNIST_IB_VAE(k=K).to(device), model.state_dict(),
                           beta_decay=BETA_DECAY)

optimizer = optim.Adam(model.parameters(), lr=LR, betas=(0.5,0.999))
scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.97)

history = dict()
history['acc']=0.
history['avg_acc']=0.
history['info_loss']=0.
history['class_loss']=0.
history['total_loss']=0.
history['epoch']=0
history['iter']=0

history_ema = dict()
history_ema['acc']=0.
history_ema['avg_acc']=0.
history_ema['info_loss']=0.
history_ema['class_loss']=0.
history_ema['total_loss']=0.
history_ema['epoch']=0
history_ema['iter']=0

keys = [
        'test_izx', 'test_izy', 'test_acc', 'test_error',
        'test_izx_ema', 'test_izy_ema', 'test_acc_ema', 'test_error_ema',
        'test_class_loss', 'test_info_loss', 'test_total_loss',
        'test_class_loss_ema', 'test_info_loss_ema', 'test_total_loss_ema',
        'train_izx', 'train_izy', 'train_acc', 'train_error', 'train_izx_ema',
        'train_izy_ema', 'train_acc_ema', 'train_error_ema',
        'train_class_loss', 'train_info_loss', 'train_total_loss'
        ]
book_keeper = {key: [] for key in keys}

iterations = 0
epoch = 0

# %% [markdown]
# ### Train loop

# %%
model.train()
model_ema.model.train()

for e in range(EPOCHS):
    total_num = 0
    epoch_iterations = 0
    epoch_class_loss = 0
    epoch_info_loss = 0
    epoch_total_loss = 0
    epoch_izy_bound = 0
    epoch_izx_bound = 0
    epoch_correct = 0
    correct = 0

    for idx, (images, labels) in enumerate(train_loader):
        iterations += 1

        x = images.to(device)
        y = labels.to(device)
        (mu, std), logit = model(x)

        class_loss = F.cross_entropy(logit, y).div(math.log(2)) # div(log(2)) -> transfer to bits
        info_loss = -0.5 * (1 + 2 * std.log() - mu.pow(2) - std.pow(2)).sum(1).mean().div(math.log(2))
        total_loss = class_loss + BETA * info_loss

        izy_bound = math.log(10, 2) - class_loss
        izx_bound = info_loss

        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        # A secondary smoothed network for comparison
        model_ema.update(model.state_dict())

        prediction = F.softmax(logit, dim=1).max(1)[1]
        accuracy = torch.eq(prediction, y).float().mean()

        # TODO: change this to MC sampling 
        avg_accuracy = torch.zeros(accuracy.size()).to(device)

        # book keeping
        epoch_class_loss += class_loss
        info_loss += info_loss
        total_loss += total_loss
        correct += torch.eq(prediction, y).float().sum()
        total_num += y.size(0)
        epoch_iterations += 1

        if (iterations % 100 == 0):
            print('i:{} IZY:{:.2f} IZX:{:.2f}'
                    .format(idx+1, izy_bound.data.item(), izx_bound.data.item()), end=' ')
            print('acc:{:.4f} avg_acc:{:.4f}'
                    .format(accuracy.data.item(), avg_accuracy.data.item()), end=' ')
            print('err:{:.4f} avg_err:{:.4f}'
                    .format(1-accuracy.data.item(), 1-avg_accuracy.data.item()))

    if (e % 2) == 0 and (e != 0):
        scheduler.step()

    accuracy_ = correct / total_num
    izy_bound /= epoch_iterations
    izx_bound /= total_num
    class_loss /= total_num
    info_loss /= total_num
    total_loss /= total_num

    book_keeper['train_izx'].append(izx_bound.data.item())
    book_keeper['train_izy'].append(izy_bound.data.item())
    book_keeper['train_acc'].append(accuracy_.data.item())
    book_keeper['train_error'].append(1 - accuracy_.data.item())
    book_keeper['train_class_loss'].append(class_loss.data.item())
    book_keeper['train_info_loss'].append(info_loss.data.item())
    book_keeper['train_total_loss'].append(total_loss.data.item())

    evaluate(model, model_ema)

print("----- Training complete -----")
# Out:
# i:100 IZY:2.06 IZX:1167.85 acc:0.7500 avg_acc:0.0000 err:0.2500 avg_err:1.0000
# i:200 IZY:2.47 IZX:850.35 acc:0.8300 avg_acc:0.0000 err:0.1700 avg_err:1.0000
# i:300 IZY:2.46 IZX:807.24 acc:0.7800 avg_acc:0.0000 err:0.2200 avg_err:1.0000
# i:400 IZY:2.62 IZX:721.39 acc:0.8000 avg_acc:0.0000 err:0.2000 avg_err:1.0000
# i:500 IZY:2.62 IZX:578.71 acc:0.8500 avg_acc:0.0000 err:0.1500 avg_err:1.0000
# i:600 IZY:2.59 IZX:621.31 acc:0.7800 avg_acc:0.0000 err:0.2200 avg_err:1.0000
# [TEST RESULT - regular]
# e:0 IZY:2.61 IZX:302.04 acc:0.8379 avg_acc:0.0000 err:0.1621 avg_erra:1.0000
# [TEST RESULT - ema]
# e:0 IZY:1.85 IZX:1309.10 acc:0.6919 avg_acc:0.0000 err:0.3081 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.84 IZX:547.26 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# i:200 IZY:2.88 IZX:504.13 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:300 IZY:2.54 IZX:529.30 acc:0.7900 avg_acc:0.0000 err:0.2100 avg_err:1.0000
# i:400 IZY:2.75 IZX:523.45 acc:0.8600 avg_acc:0.0000 err:0.1400 avg_err:1.0000
# i:500 IZY:2.67 IZX:452.44 acc:0.8300 avg_acc:0.0000 err:0.1700 avg_err:1.0000
# i:600 IZY:2.79 IZX:449.39 acc:0.8600 avg_acc:0.0000 err:0.1400 avg_err:1.0000
# [TEST RESULT - regular]
# e:1 IZY:2.65 IZX:229.21 acc:0.8398 avg_acc:0.0000 err:0.1602 avg_erra:1.0000
# [TEST RESULT - ema]
# e:1 IZY:2.58 IZX:883.72 acc:0.8379 avg_acc:0.0000 err:0.1621 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.76 IZX:467.30 acc:0.8500 avg_acc:0.0000 err:0.1500 avg_err:1.0000
# i:200 IZY:2.81 IZX:464.69 acc:0.8800 avg_acc:0.0000 err:0.1200 avg_err:1.0000
# i:300 IZY:2.90 IZX:369.59 acc:0.8800 avg_acc:0.0000 err:0.1200 avg_err:1.0000
# i:400 IZY:2.62 IZX:427.26 acc:0.8600 avg_acc:0.0000 err:0.1400 avg_err:1.0000
# i:500 IZY:2.88 IZX:382.99 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# i:600 IZY:2.90 IZX:426.80 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# [TEST RESULT - regular]
# e:2 IZY:2.68 IZX:217.85 acc:0.8453 avg_acc:0.0000 err:0.1547 avg_erra:1.0000
# [TEST RESULT - ema]
# e:2 IZY:2.74 IZX:584.30 acc:0.8611 avg_acc:0.0000 err:0.1389 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.77 IZX:400.52 acc:0.8300 avg_acc:0.0000 err:0.1700 avg_err:1.0000
# i:200 IZY:2.98 IZX:453.66 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:300 IZY:2.74 IZX:419.04 acc:0.8600 avg_acc:0.0000 err:0.1400 avg_err:1.0000
# i:400 IZY:2.76 IZX:411.29 acc:0.8500 avg_acc:0.0000 err:0.1500 avg_err:1.0000
# i:500 IZY:2.84 IZX:353.14 acc:0.8600 avg_acc:0.0000 err:0.1400 avg_err:1.0000
# i:600 IZY:2.78 IZX:430.54 acc:0.8500 avg_acc:0.0000 err:0.1500 avg_err:1.0000
# [TEST RESULT - regular]
# e:3 IZY:2.77 IZX:197.14 acc:0.8659 avg_acc:0.0000 err:0.1341 avg_erra:1.0000
# [TEST RESULT - ema]
# e:3 IZY:2.78 IZX:402.72 acc:0.8697 avg_acc:0.0000 err:0.1303 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.93 IZX:403.87 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:200 IZY:2.92 IZX:445.29 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:300 IZY:2.96 IZX:323.86 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:400 IZY:2.75 IZX:349.83 acc:0.8700 avg_acc:0.0000 err:0.1300 avg_err:1.0000
# i:500 IZY:2.89 IZX:410.73 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:2.98 IZX:321.93 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# [TEST RESULT - regular]
# e:4 IZY:2.71 IZX:165.24 acc:0.8573 avg_acc:0.0000 err:0.1427 avg_erra:1.0000
# [TEST RESULT - ema]
# e:4 IZY:2.81 IZX:300.07 acc:0.8712 avg_acc:0.0000 err:0.1288 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.94 IZX:308.46 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:200 IZY:3.07 IZX:346.64 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:300 IZY:2.70 IZX:341.30 acc:0.8400 avg_acc:0.0000 err:0.1600 avg_err:1.0000
# i:400 IZY:2.85 IZX:329.18 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:500 IZY:2.69 IZX:311.26 acc:0.8300 avg_acc:0.0000 err:0.1700 avg_err:1.0000
# i:600 IZY:2.67 IZX:316.13 acc:0.8400 avg_acc:0.0000 err:0.1600 avg_err:1.0000
# [TEST RESULT - regular]
# e:5 IZY:2.74 IZX:167.96 acc:0.8683 avg_acc:0.0000 err:0.1317 avg_erra:1.0000
# [TEST RESULT - ema]
# e:5 IZY:2.81 IZX:241.29 acc:0.8739 avg_acc:0.0000 err:0.1261 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.01 IZX:302.90 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:200 IZY:2.91 IZX:318.56 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:300 IZY:2.93 IZX:304.58 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:400 IZY:2.94 IZX:349.74 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:500 IZY:2.97 IZX:307.46 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:2.92 IZX:297.79 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# [TEST RESULT - regular]
# e:6 IZY:2.77 IZX:155.43 acc:0.8692 avg_acc:0.0000 err:0.1308 avg_erra:1.0000
# [TEST RESULT - ema]
# e:6 IZY:2.82 IZX:206.83 acc:0.8759 avg_acc:0.0000 err:0.1241 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.86 IZX:340.67 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# i:200 IZY:2.98 IZX:294.62 acc:0.8700 avg_acc:0.0000 err:0.1300 avg_err:1.0000
# i:300 IZY:2.97 IZX:309.57 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:400 IZY:2.78 IZX:296.60 acc:0.8700 avg_acc:0.0000 err:0.1300 avg_err:1.0000
# i:500 IZY:2.94 IZX:310.27 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:600 IZY:3.07 IZX:285.52 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# [TEST RESULT - regular]
# e:7 IZY:2.77 IZX:140.09 acc:0.8712 avg_acc:0.0000 err:0.1288 avg_erra:1.0000
# [TEST RESULT - ema]
# e:7 IZY:2.83 IZX:184.93 acc:0.8811 avg_acc:0.0000 err:0.1189 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:2.95 IZX:330.86 acc:0.9000 avg_acc:0.0000 err:0.1000 avg_err:1.0000
# i:200 IZY:3.05 IZX:266.97 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:300 IZY:3.06 IZX:287.46 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:400 IZY:3.16 IZX:217.53 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.07 IZX:243.52 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:2.99 IZX:243.37 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# [TEST RESULT - regular]
# e:8 IZY:2.73 IZX:122.18 acc:0.8707 avg_acc:0.0000 err:0.1293 avg_erra:1.0000
# [TEST RESULT - ema]
# e:8 IZY:2.83 IZX:168.77 acc:0.8830 avg_acc:0.0000 err:0.1170 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.15 IZX:257.78 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:200 IZY:2.93 IZX:277.64 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:300 IZY:3.03 IZX:269.98 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:400 IZY:3.04 IZX:254.63 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:500 IZY:3.00 IZX:300.85 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:3.21 IZX:223.27 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:9 IZY:2.76 IZX:131.54 acc:0.8754 avg_acc:0.0000 err:0.1246 avg_erra:1.0000
# [TEST RESULT - ema]
# e:9 IZY:2.84 IZX:156.75 acc:0.8879 avg_acc:0.0000 err:0.1121 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.03 IZX:290.55 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:200 IZY:3.01 IZX:257.35 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:300 IZY:3.12 IZX:239.94 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:400 IZY:3.12 IZX:289.74 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:500 IZY:2.99 IZX:241.02 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:3.11 IZX:209.36 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# [TEST RESULT - regular]
# e:10 IZY:2.78 IZX:122.33 acc:0.8784 avg_acc:0.0000 err:0.1216 avg_erra:1.0000
# [TEST RESULT - ema]
# e:10 IZY:2.84 IZX:146.94 acc:0.8882 avg_acc:0.0000 err:0.1118 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.05 IZX:228.26 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:200 IZY:2.95 IZX:254.97 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:300 IZY:3.20 IZX:208.84 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:400 IZY:3.03 IZX:202.39 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:500 IZY:3.01 IZX:234.52 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:600 IZY:2.96 IZX:225.65 acc:0.8800 avg_acc:0.0000 err:0.1200 avg_err:1.0000
# [TEST RESULT - regular]
# e:11 IZY:2.73 IZX:114.32 acc:0.8725 avg_acc:0.0000 err:0.1275 avg_erra:1.0000
# [TEST RESULT - ema]
# e:11 IZY:2.85 IZX:137.51 acc:0.8886 avg_acc:0.0000 err:0.1114 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.08 IZX:203.59 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:200 IZY:3.09 IZX:221.06 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:300 IZY:3.01 IZX:225.43 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:400 IZY:2.95 IZX:255.97 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:500 IZY:3.05 IZX:227.78 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:3.07 IZX:220.04 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:12 IZY:2.78 IZX:118.70 acc:0.8801 avg_acc:0.0000 err:0.1199 avg_erra:1.0000
# [TEST RESULT - ema]
# e:12 IZY:2.84 IZX:131.13 acc:0.8881 avg_acc:0.0000 err:0.1119 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:2.91 IZX:234.32 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:200 IZY:2.97 IZX:200.34 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:300 IZY:3.15 IZX:241.55 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:400 IZY:3.01 IZX:253.61 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:500 IZY:3.22 IZX:215.33 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.17 IZX:207.50 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# [TEST RESULT - regular]
# e:13 IZY:2.78 IZX:107.38 acc:0.8843 avg_acc:0.0000 err:0.1157 avg_erra:1.0000
# [TEST RESULT - ema]
# e:13 IZY:2.84 IZX:124.75 acc:0.8918 avg_acc:0.0000 err:0.1082 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.08 IZX:229.45 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:200 IZY:3.08 IZX:196.35 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:300 IZY:2.88 IZX:208.19 acc:0.8700 avg_acc:0.0000 err:0.1300 avg_err:1.0000
# i:400 IZY:3.18 IZX:197.30 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:500 IZY:3.06 IZX:204.97 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:600 IZY:3.03 IZX:244.25 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# [TEST RESULT - regular]
# e:14 IZY:2.80 IZX:121.03 acc:0.8833 avg_acc:0.0000 err:0.1167 avg_erra:1.0000
# [TEST RESULT - ema]
# e:14 IZY:2.83 IZX:118.31 acc:0.8914 avg_acc:0.0000 err:0.1086 avg_erra:1.0000
#
# i:100 IZY:3.13 IZX:200.28 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:200 IZY:2.98 IZX:240.09 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:300 IZY:3.06 IZX:197.54 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:400 IZY:2.98 IZX:193.45 acc:0.8900 avg_acc:0.0000 err:0.1100 avg_err:1.0000
# i:500 IZY:3.05 IZX:194.41 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:600 IZY:3.11 IZX:197.35 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:15 IZY:2.77 IZX:98.55 acc:0.8865 avg_acc:0.0000 err:0.1135 avg_erra:1.0000
# [TEST RESULT - ema]
# e:15 IZY:2.84 IZX:112.87 acc:0.8917 avg_acc:0.0000 err:0.1083 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:3.23 IZX:191.48 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.01 IZX:187.92 acc:0.9200 avg_acc:0.0000 err:0.0800 avg_err:1.0000
# i:300 IZY:3.22 IZX:187.86 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:400 IZY:3.19 IZX:172.29 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.09 IZX:237.15 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:600 IZY:3.02 IZX:174.74 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# [TEST RESULT - regular]
# e:16 IZY:2.78 IZX:94.86 acc:0.8842 avg_acc:0.0000 err:0.1158 avg_erra:1.0000
# [TEST RESULT - ema]
# e:16 IZY:2.84 IZX:107.68 acc:0.8944 avg_acc:0.0000 err:0.1056 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.14 IZX:169.92 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:200 IZY:3.16 IZX:176.60 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:300 IZY:3.03 IZX:186.40 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:400 IZY:3.12 IZX:192.78 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.16 IZX:177.71 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:600 IZY:3.05 IZX:208.46 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:17 IZY:2.79 IZX:95.50 acc:0.8880 avg_acc:0.0000 err:0.1120 avg_erra:1.0000
# [TEST RESULT - ema]
# e:17 IZY:2.83 IZX:103.31 acc:0.8960 avg_acc:0.0000 err:0.1040 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.09 IZX:164.75 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:200 IZY:3.25 IZX:181.31 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.14 IZX:179.42 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:400 IZY:3.20 IZX:178.99 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.20 IZX:171.25 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.07 IZX:199.62 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:18 IZY:2.75 IZX:97.17 acc:0.8855 avg_acc:0.0000 err:0.1145 avg_erra:1.0000
# [TEST RESULT - ema]
# e:18 IZY:2.83 IZX:99.34 acc:0.8954 avg_acc:0.0000 err:0.1046 avg_erra:1.0000
#
# i:100 IZY:3.17 IZX:175.55 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.11 IZX:194.44 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:300 IZY:3.11 IZX:164.50 acc:0.9100 avg_acc:0.0000 err:0.0900 avg_err:1.0000
# i:400 IZY:3.21 IZX:192.63 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.04 IZX:180.58 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:600 IZY:3.18 IZX:162.96 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# [TEST RESULT - regular]
# e:19 IZY:2.77 IZX:92.46 acc:0.8840 avg_acc:0.0000 err:0.1160 avg_erra:1.0000
# [TEST RESULT - ema]
# e:19 IZY:2.84 IZX:95.37 acc:0.8965 avg_acc:0.0000 err:0.1035 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.21 IZX:172.69 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.19 IZX:199.94 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:300 IZY:3.14 IZX:178.55 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:400 IZY:3.14 IZX:154.52 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.14 IZX:159.33 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:600 IZY:3.08 IZX:186.78 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# [TEST RESULT - regular]
# e:20 IZY:2.74 IZX:84.97 acc:0.8857 avg_acc:0.0000 err:0.1143 avg_erra:1.0000
# [TEST RESULT - ema]
# e:20 IZY:2.81 IZX:91.93 acc:0.8954 avg_acc:0.0000 err:0.1046 avg_erra:1.0000
#
# i:100 IZY:3.24 IZX:188.10 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.25 IZX:163.93 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.18 IZX:224.38 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:400 IZY:3.22 IZX:160.58 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.16 IZX:165.45 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.16 IZX:154.64 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# [TEST RESULT - regular]
# e:21 IZY:2.74 IZX:78.68 acc:0.8852 avg_acc:0.0000 err:0.1148 avg_erra:1.0000
# [TEST RESULT - ema]
# e:21 IZY:2.81 IZX:89.16 acc:0.8960 avg_acc:0.0000 err:0.1040 avg_erra:1.0000
#
# i:100 IZY:3.19 IZX:155.92 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.22 IZX:173.82 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:2.98 IZX:161.61 acc:0.9300 avg_acc:0.0000 err:0.0700 avg_err:1.0000
# i:400 IZY:3.20 IZX:159.99 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.19 IZX:186.15 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:2.98 IZX:141.48 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# [TEST RESULT - regular]
# e:22 IZY:2.74 IZX:78.30 acc:0.8852 avg_acc:0.0000 err:0.1148 avg_erra:1.0000
# [TEST RESULT - ema]
# e:22 IZY:2.81 IZX:86.48 acc:0.8968 avg_acc:0.0000 err:0.1032 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.22 IZX:156.10 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:200 IZY:3.21 IZX:157.27 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.15 IZX:145.87 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:400 IZY:3.25 IZX:164.21 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.15 IZX:172.88 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:600 IZY:3.26 IZX:151.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:23 IZY:2.75 IZX:76.88 acc:0.8877 avg_acc:0.0000 err:0.1123 avg_erra:1.0000
# [TEST RESULT - ema]
# e:23 IZY:2.81 IZX:83.94 acc:0.8980 avg_acc:0.0000 err:0.1020 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.11 IZX:151.81 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:200 IZY:3.27 IZX:147.41 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.23 IZX:154.47 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:400 IZY:3.23 IZX:142.30 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.19 IZX:150.81 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.22 IZX:168.46 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:24 IZY:2.73 IZX:77.95 acc:0.8870 avg_acc:0.0000 err:0.1130 avg_erra:1.0000
# [TEST RESULT - ema]
# e:24 IZY:2.80 IZX:81.63 acc:0.8965 avg_acc:0.0000 err:0.1035 avg_erra:1.0000
#
# i:100 IZY:3.22 IZX:152.94 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.23 IZX:166.11 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.20 IZX:139.77 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:400 IZY:3.27 IZX:134.49 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.08 IZX:154.37 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# i:600 IZY:3.25 IZX:151.92 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:25 IZY:2.75 IZX:72.06 acc:0.8909 avg_acc:0.0000 err:0.1091 avg_erra:1.0000
# [TEST RESULT - ema]
# e:25 IZY:2.79 IZX:79.46 acc:0.8984 avg_acc:0.0000 err:0.1016 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.11 IZX:153.22 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:200 IZY:3.29 IZX:147.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.24 IZX:159.96 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:400 IZY:3.26 IZX:154.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.22 IZX:143.78 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.18 IZX:156.00 acc:0.9400 avg_acc:0.0000 err:0.0600 avg_err:1.0000
# [TEST RESULT - regular]
# e:26 IZY:2.74 IZX:74.17 acc:0.8893 avg_acc:0.0000 err:0.1107 avg_erra:1.0000
# [TEST RESULT - ema]
# e:26 IZY:2.79 IZX:77.69 acc:0.8983 avg_acc:0.0000 err:0.1017 avg_erra:1.0000
#
# i:100 IZY:3.20 IZX:155.63 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.25 IZX:139.02 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.27 IZX:137.89 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.23 IZX:154.47 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.20 IZX:154.70 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:600 IZY:3.24 IZX:138.67 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:27 IZY:2.72 IZX:76.46 acc:0.8896 avg_acc:0.0000 err:0.1104 avg_erra:1.0000
# [TEST RESULT - ema]
# e:27 IZY:2.78 IZX:75.92 acc:0.8971 avg_acc:0.0000 err:0.1029 avg_erra:1.0000
#
# i:100 IZY:3.20 IZX:149.60 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.12 IZX:144.58 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:300 IZY:3.22 IZX:150.44 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.27 IZX:147.50 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.16 IZX:136.64 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:600 IZY:3.15 IZX:156.65 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# [TEST RESULT - regular]
# e:28 IZY:2.72 IZX:76.91 acc:0.8929 avg_acc:0.0000 err:0.1071 avg_erra:1.0000
# [TEST RESULT - ema]
# e:28 IZY:2.77 IZX:74.52 acc:0.8949 avg_acc:0.0000 err:0.1051 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:3.21 IZX:139.69 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:200 IZY:3.26 IZX:152.33 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.13 IZX:145.05 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:400 IZY:3.28 IZX:135.71 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.16 IZX:130.27 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.22 IZX:139.56 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:29 IZY:2.67 IZX:66.31 acc:0.8836 avg_acc:0.0000 err:0.1164 avg_erra:1.0000
# [TEST RESULT - ema]
# e:29 IZY:2.76 IZX:73.00 acc:0.8945 avg_acc:0.0000 err:0.1055 avg_erra:1.0000
#
# i:100 IZY:3.18 IZX:141.37 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:200 IZY:3.28 IZX:120.62 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.19 IZX:159.20 acc:0.9500 avg_acc:0.0000 err:0.0500 avg_err:1.0000
# i:400 IZY:3.25 IZX:129.93 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.27 IZX:129.99 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.20 IZX:133.06 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:30 IZY:2.70 IZX:67.17 acc:0.8907 avg_acc:0.0000 err:0.1093 avg_erra:1.0000
# [TEST RESULT - ema]
# e:30 IZY:2.76 IZX:71.12 acc:0.8947 avg_acc:0.0000 err:0.1053 avg_erra:1.0000
#
# i:100 IZY:3.26 IZX:127.18 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.28 IZX:130.21 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.26 IZX:141.15 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.19 IZX:131.97 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.25 IZX:140.25 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.26 IZX:146.75 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:31 IZY:2.70 IZX:76.91 acc:0.8923 avg_acc:0.0000 err:0.1077 avg_erra:1.0000
# [TEST RESULT - ema]
# e:31 IZY:2.74 IZX:69.50 acc:0.8972 avg_acc:0.0000 err:0.1028 avg_erra:1.0000
#
# i:100 IZY:3.22 IZX:134.79 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.30 IZX:143.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:160.54 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.13 IZX:136.50 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# i:500 IZY:3.26 IZX:141.62 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.28 IZX:126.28 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:32 IZY:2.69 IZX:62.84 acc:0.8909 avg_acc:0.0000 err:0.1091 avg_erra:1.0000
# [TEST RESULT - ema]
# e:32 IZY:2.74 IZX:68.20 acc:0.8969 avg_acc:0.0000 err:0.1031 avg_erra:1.0000
#
# i:100 IZY:3.26 IZX:127.68 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.25 IZX:125.42 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.26 IZX:128.23 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.26 IZX:131.08 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.31 IZX:118.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.25 IZX:157.94 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:33 IZY:2.70 IZX:70.04 acc:0.8921 avg_acc:0.0000 err:0.1079 avg_erra:1.0000
# [TEST RESULT - ema]
# e:33 IZY:2.74 IZX:66.96 acc:0.8979 avg_acc:0.0000 err:0.1021 avg_erra:1.0000
#
# i:100 IZY:3.26 IZX:118.68 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.19 IZX:127.96 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.29 IZX:147.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:126.31 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.15 IZX:128.27 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.25 IZX:129.36 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:34 IZY:2.66 IZX:63.34 acc:0.8902 avg_acc:0.0000 err:0.1098 avg_erra:1.0000
# [TEST RESULT - ema]
# e:34 IZY:2.72 IZX:65.82 acc:0.8972 avg_acc:0.0000 err:0.1028 avg_erra:1.0000
#
# i:100 IZY:3.29 IZX:142.38 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.28 IZX:127.47 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.29 IZX:125.83 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.27 IZX:132.14 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.24 IZX:130.08 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.26 IZX:130.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:35 IZY:2.65 IZX:63.55 acc:0.8924 avg_acc:0.0000 err:0.1076 avg_erra:1.0000
# [TEST RESULT - ema]
# e:35 IZY:2.73 IZX:65.06 acc:0.9002 avg_acc:0.0000 err:0.0998 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.30 IZX:123.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.27 IZX:118.58 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.28 IZX:140.29 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.26 IZX:118.49 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.28 IZX:127.78 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.30 IZX:118.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:36 IZY:2.64 IZX:60.14 acc:0.8899 avg_acc:0.0000 err:0.1101 avg_erra:1.0000
# [TEST RESULT - ema]
# e:36 IZY:2.69 IZX:64.27 acc:0.8957 avg_acc:0.0000 err:0.1043 avg_erra:1.0000
#
# i:100 IZY:3.20 IZX:135.32 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.30 IZX:111.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.26 IZX:126.95 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.27 IZX:121.74 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.23 IZX:124.66 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.22 IZX:123.31 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:37 IZY:2.61 IZX:59.36 acc:0.8899 avg_acc:0.0000 err:0.1101 avg_erra:1.0000
# [TEST RESULT - ema]
# e:37 IZY:2.69 IZX:63.40 acc:0.8925 avg_acc:0.0000 err:0.1075 avg_erra:1.0000
#
# i:100 IZY:3.28 IZX:131.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:134.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.24 IZX:118.70 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.27 IZX:124.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.27 IZX:133.26 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.28 IZX:138.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:38 IZY:2.58 IZX:68.51 acc:0.8897 avg_acc:0.0000 err:0.1103 avg_erra:1.0000
# [TEST RESULT - ema]
# e:38 IZY:2.69 IZX:62.51 acc:0.8985 avg_acc:0.0000 err:0.1015 avg_erra:1.0000
#
# i:100 IZY:3.21 IZX:123.34 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.27 IZX:117.20 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.30 IZX:113.30 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.30 IZX:125.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.25 IZX:128.11 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.25 IZX:121.62 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:39 IZY:2.64 IZX:60.32 acc:0.8918 avg_acc:0.0000 err:0.1082 avg_erra:1.0000
# [TEST RESULT - ema]
# e:39 IZY:2.69 IZX:61.60 acc:0.8983 avg_acc:0.0000 err:0.1017 avg_erra:1.0000
#
# i:100 IZY:3.27 IZX:120.98 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.27 IZX:128.71 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.22 IZX:128.31 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.26 IZX:131.16 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:500 IZY:3.28 IZX:123.31 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.29 IZX:117.15 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:40 IZY:2.61 IZX:60.55 acc:0.8903 avg_acc:0.0000 err:0.1097 avg_erra:1.0000
# [TEST RESULT - ema]
# e:40 IZY:2.68 IZX:61.15 acc:0.8990 avg_acc:0.0000 err:0.1010 avg_erra:1.0000
#
# i:100 IZY:3.27 IZX:126.87 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.30 IZX:112.54 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.26 IZX:128.71 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.26 IZX:135.34 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.27 IZX:141.07 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.25 IZX:127.89 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:41 IZY:2.59 IZX:59.38 acc:0.8906 avg_acc:0.0000 err:0.1094 avg_erra:1.0000
# [TEST RESULT - ema]
# e:41 IZY:2.67 IZX:60.18 acc:0.8983 avg_acc:0.0000 err:0.1017 avg_erra:1.0000
#
# i:100 IZY:3.21 IZX:123.96 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:200 IZY:3.29 IZX:113.23 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.25 IZX:123.02 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.30 IZX:115.54 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.26 IZX:126.30 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.28 IZX:135.25 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:42 IZY:2.62 IZX:67.23 acc:0.8928 avg_acc:0.0000 err:0.1072 avg_erra:1.0000
# [TEST RESULT - ema]
# e:42 IZY:2.67 IZX:59.35 acc:0.8981 avg_acc:0.0000 err:0.1019 avg_erra:1.0000
#
# i:100 IZY:3.28 IZX:116.36 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.25 IZX:118.18 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:300 IZY:3.29 IZX:105.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:110.63 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.30 IZX:110.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:120.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:43 IZY:2.61 IZX:60.11 acc:0.8915 avg_acc:0.0000 err:0.1085 avg_erra:1.0000
# [TEST RESULT - ema]
# e:43 IZY:2.66 IZX:58.23 acc:0.8992 avg_acc:0.0000 err:0.1008 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:113.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:119.54 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.24 IZX:114.84 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:400 IZY:3.31 IZX:111.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:121.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:114.54 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:44 IZY:2.61 IZX:54.28 acc:0.8940 avg_acc:0.0000 err:0.1060 avg_erra:1.0000
# [TEST RESULT - ema]
# e:44 IZY:2.66 IZX:57.16 acc:0.8986 avg_acc:0.0000 err:0.1014 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:3.25 IZX:120.83 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.24 IZX:113.29 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.27 IZX:109.63 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:110.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.23 IZX:115.13 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:600 IZY:3.32 IZX:103.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:45 IZY:2.58 IZX:54.31 acc:0.8916 avg_acc:0.0000 err:0.1084 avg_erra:1.0000
# [TEST RESULT - ema]
# e:45 IZY:2.64 IZX:56.41 acc:0.8987 avg_acc:0.0000 err:0.1013 avg_erra:1.0000
#
# i:100 IZY:3.29 IZX:117.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.26 IZX:120.34 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.30 IZX:108.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:110.36 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.29 IZX:101.25 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.24 IZX:110.26 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# [TEST RESULT - regular]
# e:46 IZY:2.60 IZX:58.96 acc:0.8935 avg_acc:0.0000 err:0.1065 avg_erra:1.0000
# [TEST RESULT - ema]
# e:46 IZY:2.65 IZX:56.28 acc:0.9005 avg_acc:0.0000 err:0.0995 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model_ema.h5
# i:100 IZY:3.29 IZX:104.73 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.29 IZX:110.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:107.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:111.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.29 IZX:104.70 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.30 IZX:113.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:47 IZY:2.59 IZX:54.56 acc:0.8909 avg_acc:0.0000 err:0.1091 avg_erra:1.0000
# [TEST RESULT - ema]
# e:47 IZY:2.62 IZX:55.51 acc:0.8950 avg_acc:0.0000 err:0.1050 avg_erra:1.0000
#
# i:100 IZY:3.25 IZX:104.76 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.26 IZX:108.93 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.22 IZX:110.26 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:400 IZY:3.31 IZX:112.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.26 IZX:120.46 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.29 IZX:117.03 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:48 IZY:2.58 IZX:53.85 acc:0.8921 avg_acc:0.0000 err:0.1079 avg_erra:1.0000
# [TEST RESULT - ema]
# e:48 IZY:2.64 IZX:55.08 acc:0.8979 avg_acc:0.0000 err:0.1021 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:107.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:100.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:111.78 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.31 IZX:112.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:106.91 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.22 IZX:110.64 acc:0.9600 avg_acc:0.0000 err:0.0400 avg_err:1.0000
# [TEST RESULT - regular]
# e:49 IZY:2.60 IZX:62.33 acc:0.8943 avg_acc:0.0000 err:0.1057 avg_erra:1.0000
# [TEST RESULT - ema]
# e:49 IZY:2.62 IZX:54.31 acc:0.8966 avg_acc:0.0000 err:0.1034 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:3.30 IZX:101.62 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:106.06 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:105.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.30 IZX:108.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:117.64 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.27 IZX:108.41 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:50 IZY:2.56 IZX:57.06 acc:0.8907 avg_acc:0.0000 err:0.1093 avg_erra:1.0000
# [TEST RESULT - ema]
# e:50 IZY:2.60 IZX:53.83 acc:0.8972 avg_acc:0.0000 err:0.1028 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:93.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.27 IZX:102.75 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.31 IZX:108.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:119.90 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.30 IZX:112.55 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:109.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:51 IZY:2.57 IZX:51.94 acc:0.8918 avg_acc:0.0000 err:0.1082 avg_erra:1.0000
# [TEST RESULT - ema]
# e:51 IZY:2.60 IZX:53.35 acc:0.8966 avg_acc:0.0000 err:0.1034 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:94.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.23 IZX:97.83 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.30 IZX:105.20 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:113.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:109.86 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:104.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:52 IZY:2.55 IZX:51.99 acc:0.8941 avg_acc:0.0000 err:0.1059 avg_erra:1.0000
# [TEST RESULT - ema]
# e:52 IZY:2.60 IZX:52.76 acc:0.8978 avg_acc:0.0000 err:0.1022 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:99.29 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.28 IZX:102.06 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:100.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.28 IZX:107.15 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.30 IZX:111.00 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:101.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:53 IZY:2.56 IZX:51.43 acc:0.8935 avg_acc:0.0000 err:0.1065 avg_erra:1.0000
# [TEST RESULT - ema]
# e:53 IZY:2.59 IZX:52.28 acc:0.8981 avg_acc:0.0000 err:0.1019 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:110.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:102.20 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.28 IZX:105.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.29 IZX:99.38 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.30 IZX:104.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.28 IZX:102.78 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:54 IZY:2.53 IZX:49.02 acc:0.8886 avg_acc:0.0000 err:0.1114 avg_erra:1.0000
# [TEST RESULT - ema]
# e:54 IZY:2.59 IZX:51.72 acc:0.8971 avg_acc:0.0000 err:0.1029 avg_erra:1.0000
#
# i:100 IZY:3.28 IZX:102.83 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.30 IZX:108.48 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.30 IZX:113.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.28 IZX:99.12 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.29 IZX:101.46 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.31 IZX:95.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:55 IZY:2.51 IZX:49.64 acc:0.8937 avg_acc:0.0000 err:0.1063 avg_erra:1.0000
# [TEST RESULT - ema]
# e:55 IZY:2.58 IZX:51.24 acc:0.8977 avg_acc:0.0000 err:0.1023 avg_erra:1.0000
#
# i:100 IZY:3.28 IZX:120.30 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:109.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.29 IZX:103.50 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.27 IZX:106.16 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.31 IZX:97.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.29 IZX:104.67 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:56 IZY:2.54 IZX:49.36 acc:0.8924 avg_acc:0.0000 err:0.1076 avg_erra:1.0000
# [TEST RESULT - ema]
# e:56 IZY:2.57 IZX:50.65 acc:0.8981 avg_acc:0.0000 err:0.1019 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:104.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:102.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:101.15 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:95.33 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.26 IZX:104.10 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.28 IZX:100.95 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:57 IZY:2.52 IZX:50.74 acc:0.8937 avg_acc:0.0000 err:0.1063 avg_erra:1.0000
# [TEST RESULT - ema]
# e:57 IZY:2.57 IZX:50.14 acc:0.8966 avg_acc:0.0000 err:0.1034 avg_erra:1.0000
#
# i:100 IZY:3.29 IZX:105.03 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.27 IZX:105.49 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:300 IZY:3.32 IZX:97.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:99.53 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.27 IZX:95.89 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.26 IZX:94.25 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:58 IZY:2.51 IZX:49.19 acc:0.8923 avg_acc:0.0000 err:0.1077 avg_erra:1.0000
# [TEST RESULT - ema]
# e:58 IZY:2.56 IZX:49.81 acc:0.8945 avg_acc:0.0000 err:0.1055 avg_erra:1.0000
#
# i:100 IZY:3.27 IZX:107.18 acc:0.9700 avg_acc:0.0000 err:0.0300 avg_err:1.0000
# i:200 IZY:3.29 IZX:98.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.27 IZX:100.96 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.25 IZX:105.37 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:500 IZY:3.29 IZX:107.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:95.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:59 IZY:2.53 IZX:47.10 acc:0.8949 avg_acc:0.0000 err:0.1051 avg_erra:1.0000
# [TEST RESULT - ema]
# e:59 IZY:2.57 IZX:49.54 acc:0.8994 avg_acc:0.0000 err:0.1006 avg_erra:1.0000
#
# Saved model to /content/drive/MyDrive/AML_project/saved_models/fmnist_model.h5
# i:100 IZY:3.29 IZX:93.76 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:110.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:97.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:102.55 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:100.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.24 IZX:93.96 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:60 IZY:2.49 IZX:47.84 acc:0.8864 avg_acc:0.0000 err:0.1136 avg_erra:1.0000
# [TEST RESULT - ema]
# e:60 IZY:2.56 IZX:49.03 acc:0.8967 avg_acc:0.0000 err:0.1033 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:92.12 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:95.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:95.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:96.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.28 IZX:93.29 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.31 IZX:104.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:61 IZY:2.52 IZX:48.46 acc:0.8928 avg_acc:0.0000 err:0.1072 avg_erra:1.0000
# [TEST RESULT - ema]
# e:61 IZY:2.56 IZX:48.57 acc:0.8956 avg_acc:0.0000 err:0.1044 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:102.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:98.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:96.14 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.30 IZX:88.77 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.27 IZX:90.43 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.29 IZX:97.86 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:62 IZY:2.50 IZX:49.79 acc:0.8947 avg_acc:0.0000 err:0.1053 avg_erra:1.0000
# [TEST RESULT - ema]
# e:62 IZY:2.56 IZX:48.06 acc:0.8977 avg_acc:0.0000 err:0.1023 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:96.34 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.29 IZX:109.79 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:93.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.29 IZX:102.13 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.28 IZX:91.58 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# i:600 IZY:3.29 IZX:98.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:63 IZY:2.54 IZX:47.34 acc:0.8927 avg_acc:0.0000 err:0.1073 avg_erra:1.0000
# [TEST RESULT - ema]
# e:63 IZY:2.56 IZX:47.56 acc:0.8972 avg_acc:0.0000 err:0.1028 avg_erra:1.0000
#
# i:100 IZY:3.30 IZX:107.87 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.31 IZX:91.77 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:98.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.28 IZX:95.53 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:94.45 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:92.30 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:64 IZY:2.51 IZX:47.29 acc:0.8908 avg_acc:0.0000 err:0.1092 avg_erra:1.0000
# [TEST RESULT - ema]
# e:64 IZY:2.54 IZX:47.33 acc:0.8949 avg_acc:0.0000 err:0.1051 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:97.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:86.25 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:96.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:95.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:97.07 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.27 IZX:102.49 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# [TEST RESULT - regular]
# e:65 IZY:2.51 IZX:51.83 acc:0.8939 avg_acc:0.0000 err:0.1061 avg_erra:1.0000
# [TEST RESULT - ema]
# e:65 IZY:2.55 IZX:46.77 acc:0.8978 avg_acc:0.0000 err:0.1022 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:91.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:103.36 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.31 IZX:91.51 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:91.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:93.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:91.12 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:66 IZY:2.50 IZX:44.67 acc:0.8937 avg_acc:0.0000 err:0.1063 avg_erra:1.0000
# [TEST RESULT - ema]
# e:66 IZY:2.55 IZX:46.37 acc:0.8932 avg_acc:0.0000 err:0.1068 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:106.69 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.29 IZX:93.01 acc:0.9800 avg_acc:0.0000 err:0.0200 avg_err:1.0000
# ...
#
# i:100 IZY:3.31 IZX:63.94 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:65.02 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.26 IZX:62.01 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:60.92 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:68.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:59.77 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:176 IZY:2.36 IZX:30.97 acc:0.8909 avg_acc:0.0000 err:0.1091 avg_erra:1.0000
# [TEST RESULT - ema]
# e:176 IZY:2.39 IZX:30.92 acc:0.8928 avg_acc:0.0000 err:0.1072 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:64.80 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.15 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:64.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:64.53 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:66.31 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:62.56 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:177 IZY:2.39 IZX:30.76 acc:0.8955 avg_acc:0.0000 err:0.1045 avg_erra:1.0000
# [TEST RESULT - ema]
# e:177 IZY:2.39 IZX:30.99 acc:0.8931 avg_acc:0.0000 err:0.1069 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:64.40 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:66.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:63.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:67.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:63.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:65.75 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:178 IZY:2.38 IZX:30.75 acc:0.8942 avg_acc:0.0000 err:0.1058 avg_erra:1.0000
# [TEST RESULT - ema]
# e:178 IZY:2.39 IZX:30.94 acc:0.8949 avg_acc:0.0000 err:0.1051 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:64.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:59.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.30 IZX:62.06 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.52 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:62.03 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:62.28 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:179 IZY:2.37 IZX:30.45 acc:0.8951 avg_acc:0.0000 err:0.1049 avg_erra:1.0000
# [TEST RESULT - ema]
# e:179 IZY:2.38 IZX:30.89 acc:0.8940 avg_acc:0.0000 err:0.1060 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:62.14 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:65.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:64.66 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:65.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:59.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.10 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:180 IZY:2.38 IZX:30.95 acc:0.8950 avg_acc:0.0000 err:0.1050 avg_erra:1.0000
# [TEST RESULT - ema]
# e:180 IZY:2.36 IZX:30.81 acc:0.8921 avg_acc:0.0000 err:0.1079 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:62.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:63.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:60.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.62 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:68.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.71 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:181 IZY:2.37 IZX:30.79 acc:0.8905 avg_acc:0.0000 err:0.1095 avg_erra:1.0000
# [TEST RESULT - ema]
# e:181 IZY:2.38 IZX:30.84 acc:0.8943 avg_acc:0.0000 err:0.1057 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.37 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:63.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.87 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.29 IZX:64.81 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:62.37 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:182 IZY:2.35 IZX:30.74 acc:0.8922 avg_acc:0.0000 err:0.1078 avg_erra:1.0000
# [TEST RESULT - ema]
# e:182 IZY:2.38 IZX:30.85 acc:0.8919 avg_acc:0.0000 err:0.1081 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:65.98 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:65.19 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:68.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:66.67 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.63 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:65.96 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:183 IZY:2.40 IZX:33.57 acc:0.8941 avg_acc:0.0000 err:0.1059 avg_erra:1.0000
# [TEST RESULT - ema]
# e:183 IZY:2.40 IZX:30.89 acc:0.8923 avg_acc:0.0000 err:0.1077 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:64.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:63.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:63.34 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:62.70 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:64.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:184 IZY:2.38 IZX:30.49 acc:0.8930 avg_acc:0.0000 err:0.1070 avg_erra:1.0000
# [TEST RESULT - ema]
# e:184 IZY:2.39 IZX:30.79 acc:0.8946 avg_acc:0.0000 err:0.1054 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:61.24 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:62.44 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:62.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:61.96 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:185 IZY:2.36 IZX:30.62 acc:0.8902 avg_acc:0.0000 err:0.1098 avg_erra:1.0000
# [TEST RESULT - ema]
# e:185 IZY:2.40 IZX:30.71 acc:0.8937 avg_acc:0.0000 err:0.1063 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.60 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:59.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:62.39 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.81 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:60.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.43 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:186 IZY:2.37 IZX:30.43 acc:0.8934 avg_acc:0.0000 err:0.1066 avg_erra:1.0000
# [TEST RESULT - ema]
# e:186 IZY:2.38 IZX:30.55 acc:0.8933 avg_acc:0.0000 err:0.1067 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:60.16 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.89 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:61.78 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.62 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:187 IZY:2.37 IZX:30.55 acc:0.8918 avg_acc:0.0000 err:0.1082 avg_erra:1.0000
# [TEST RESULT - ema]
# e:187 IZY:2.40 IZX:30.57 acc:0.8942 avg_acc:0.0000 err:0.1058 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:62.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:62.53 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:61.55 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:61.92 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.66 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.22 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:188 IZY:2.39 IZX:30.46 acc:0.8949 avg_acc:0.0000 err:0.1051 avg_erra:1.0000
# [TEST RESULT - ema]
# e:188 IZY:2.40 IZX:30.55 acc:0.8930 avg_acc:0.0000 err:0.1070 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:63.61 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.31 IZX:61.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:63.74 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:65.21 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:60.73 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:61.41 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:189 IZY:2.38 IZX:30.13 acc:0.8921 avg_acc:0.0000 err:0.1079 avg_erra:1.0000
# [TEST RESULT - ema]
# e:189 IZY:2.36 IZX:30.46 acc:0.8919 avg_acc:0.0000 err:0.1081 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:61.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:60.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.31 IZX:61.77 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:62.88 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:60.91 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:190 IZY:2.38 IZX:31.10 acc:0.8928 avg_acc:0.0000 err:0.1072 avg_erra:1.0000
# [TEST RESULT - ema]
# e:190 IZY:2.41 IZX:30.48 acc:0.8960 avg_acc:0.0000 err:0.1040 avg_erra:1.0000
#
# i:100 IZY:3.27 IZX:61.34 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.35 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:65.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:62.09 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:63.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.30 IZX:63.96 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# [TEST RESULT - regular]
# e:191 IZY:2.38 IZX:30.71 acc:0.8936 avg_acc:0.0000 err:0.1064 avg_erra:1.0000
# [TEST RESULT - ema]
# e:191 IZY:2.40 IZX:30.47 acc:0.8966 avg_acc:0.0000 err:0.1034 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:64.95 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.38 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:66.92 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:400 IZY:3.32 IZX:64.62 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:61.82 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:192 IZY:2.36 IZX:30.98 acc:0.8941 avg_acc:0.0000 err:0.1059 avg_erra:1.0000
# [TEST RESULT - ema]
# e:192 IZY:2.41 IZX:30.57 acc:0.8962 avg_acc:0.0000 err:0.1038 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:65.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:61.95 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:60.49 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:59.26 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:60.30 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.68 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:193 IZY:2.35 IZX:30.54 acc:0.8922 avg_acc:0.0000 err:0.1078 avg_erra:1.0000
# [TEST RESULT - ema]
# e:193 IZY:2.37 IZX:30.47 acc:0.8944 avg_acc:0.0000 err:0.1056 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:65.04 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:64.47 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:59.31 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:56.88 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:58.76 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:60.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:194 IZY:2.33 IZX:30.00 acc:0.8914 avg_acc:0.0000 err:0.1086 avg_erra:1.0000
# [TEST RESULT - ema]
# e:194 IZY:2.40 IZX:30.38 acc:0.8921 avg_acc:0.0000 err:0.1079 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:60.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:60.99 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:60.79 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:59.77 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:63.45 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:61.48 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:195 IZY:2.38 IZX:30.60 acc:0.8943 avg_acc:0.0000 err:0.1057 avg_erra:1.0000
# [TEST RESULT - ema]
# e:195 IZY:2.37 IZX:30.26 acc:0.8942 avg_acc:0.0000 err:0.1058 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:60.65 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.30 IZX:60.28 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:300 IZY:3.32 IZX:60.36 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:63.05 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.32 IZX:63.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.31 IZX:61.88 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:196 IZY:2.38 IZX:30.92 acc:0.8941 avg_acc:0.0000 err:0.1059 avg_erra:1.0000
# [TEST RESULT - ema]
# e:196 IZY:2.36 IZX:30.26 acc:0.8913 avg_acc:0.0000 err:0.1087 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:63.15 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:62.46 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:60.59 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:64.01 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.30 IZX:63.75 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:600 IZY:3.32 IZX:61.57 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:197 IZY:2.34 IZX:30.23 acc:0.8935 avg_acc:0.0000 err:0.1065 avg_erra:1.0000
# [TEST RESULT - ema]
# e:197 IZY:2.37 IZX:30.31 acc:0.8907 avg_acc:0.0000 err:0.1093 avg_erra:1.0000
#
# i:100 IZY:3.32 IZX:59.55 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:63.17 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.32 IZX:65.33 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.32 IZX:59.91 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:500 IZY:3.31 IZX:64.18 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:62.90 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:198 IZY:2.38 IZX:30.57 acc:0.8943 avg_acc:0.0000 err:0.1057 avg_erra:1.0000
# [TEST RESULT - ema]
# e:198 IZY:2.36 IZX:30.34 acc:0.8910 avg_acc:0.0000 err:0.1090 avg_erra:1.0000
#
# i:100 IZY:3.31 IZX:64.31 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:200 IZY:3.32 IZX:59.97 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:300 IZY:3.31 IZX:58.13 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:400 IZY:3.30 IZX:62.40 acc:0.9900 avg_acc:0.0000 err:0.0100 avg_err:1.0000
# i:500 IZY:3.31 IZX:62.58 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# i:600 IZY:3.32 IZX:63.16 acc:1.0000 avg_acc:0.0000 err:0.0000 avg_err:1.0000
# [TEST RESULT - regular]
# e:199 IZY:2.35 IZX:30.11 acc:0.8937 avg_acc:0.0000 err:0.1063 avg_erra:1.0000
# [TEST RESULT - ema]
# e:199 IZY:2.38 IZX:30.21 acc:0.8928 avg_acc:0.0000 err:0.1072 avg_erra:1.0000
#
# ----- Training complete -----

# %%
with open(PICKLE_SAVE_PATH, 'wb') as f:
    pickle.dump(book_keeper, f)
